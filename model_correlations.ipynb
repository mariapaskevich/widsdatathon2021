# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
xgboost = pd.read_csv("submissions/SolutionWiDS2021_XGB_1000_epochs_best_params_fixed_bug.csv")
# lightgbm = pd.read_csv("SolutionWiDS2021_LightGBM.csv")
keras = pd.read_csv("submissions/keras_clf_bigger_nn.csv")
features_xgb = pd.read_csv("submissions/SolutionWiDS2021_XGB_1000_epochs_features_handled.csv")

# %%
plt.scatter(xgboost.diabetes_mellitus,features_xgb.diabetes_mellitus,alpha=.05)
plt.show()

# %%
pd.DataFrame([xgboost.diabetes_mellitus,features_xgb.diabetes_mellitus]).T.corr()
# Out:
#                    diabetes_mellitus  diabetes_mellitus
# diabetes_mellitus           1.000000           0.956212
# diabetes_mellitus           0.956212           1.000000

# %%
pd.DataFrame([xgboost.diabetes_mellitus,features_xgb.diabetes_mellitus]).T
# Out:
#        diabetes_mellitus  diabetes_mellitus
# 0               0.020342           0.137026
# 1               0.137026           0.147288
# 2               0.147288           0.080747
# 3               0.080747           0.551258
# 4               0.551258           0.037426
# ...                  ...                ...
# 10229           0.020048           0.163386
# 10230           0.163386           0.056627
# 10231           0.056627           0.003233
# 10232           0.003233           0.003398
# 10233           0.003398           0.500000
#
# [10234 rows x 2 columns]

# %%
xgboost['diabetes_mellitus'] = pd.DataFrame([xgboost.diabetes_mellitus,keras.diabetes_mellitus]).max()

# %%
xgboost.set_index('encounter_id').to_csv('submissions/SolutionWiDS2021_xgb_and_keras_max.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-34c6a5bf5f59> in <module>
# ----> 1 features_xgb = pd.read_csv("submissions/SolutionWiDS2021_XGB_300_epochs_best_params_3_features_replaced.csv")
#
# NameError: name 'pd' is not defined
