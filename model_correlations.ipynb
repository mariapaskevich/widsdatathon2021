# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
xgboost = pd.read_csv("SolutionWiDS2021_XGB_200_epochs_01_lr.csv")
lightgbm = pd.read_csv("SolutionWiDS2021_LightGBM.csv")

# %%
plt.scatter(xgboost.diabetes_mellitus,lightgbm.diabetes_mellitus,alpha=.05)
plt.show()

# %%
pd.DataFrame([xgboost.diabetes_mellitus,lightgbm.diabetes_mellitus]).T.corr()
# Out:
#                    diabetes_mellitus  diabetes_mellitus
# diabetes_mellitus           1.000000           0.936949
# diabetes_mellitus           0.936949           1.000000

# %%
# Out:
# 0        0.076211
# 1        0.130797
# 2        0.201990
# 3        0.095885
# 4        0.367270
#            ...
# 10229    0.099022
# 10230    0.107219
# 10231    0.115665
# 10232    0.059123
# 10233    0.049631
# Length: 10234, dtype: float64

# %%
xgboost['diabetes_mellitus'] = pd.DataFrame([xgboost.diabetes_mellitus,lightgbm.diabetes_mellitus]).mean()

# %%
xgboost.set_index('encounter_id').to_csv('SolutionWiDS2021_xgb_and_lgbm.csv')
