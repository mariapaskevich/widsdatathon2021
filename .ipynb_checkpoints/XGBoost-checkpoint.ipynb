# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
import xgboost as xgb

import wandb
from wandb.lightgbm import wandb_callback

pd.set_option("display.max_columns", 181)
pd.set_option("display.min_rows", 200)

# %%
#!pip install xgboost

# %%
data_dictionary = pd.read_csv("DataDictionaryWiDS2021.csv")
unlabeled = pd.read_csv("UnlabeledWiDS2021.csv")
training = pd.read_csv("TrainingWiDS2021.csv")

# %%
column_datatype_mapping = dict(zip(data_dictionary['Variable Name'], data_dictionary['Data Type']))

# %%
del training['Unnamed: 0']
del unlabeled['Unnamed: 0']

# %%
all_data = training.append(unlabeled).drop(['encounter_id', 
                                            'hospital_id', 
                                            'diabetes_mellitus'], axis=1)

all_data.shape
# Out:
# (140391, 177)

# %%
cat_cols = ['ethnicity', 'gender', 'hospital_admit_source',
           'icu_admit_source', 'icu_stay_type', 'icu_type',
           'apache_2_diagnosis', 'apache_3j_diagnosis','icu_id']


all_data = pd.get_dummies(all_data,dummy_na=True,columns=cat_cols)
all_data = all_data.fillna(-1)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 'mle',svd_solver = 'full')
pca.fit(all_data)
# Out:
# PCA(n_components='mle', svd_solver='full')

# %%
all_data_pca = pd.DataFrame(pca.transform(all_data))

# %%
df_train = all_data_pca[:len(training)]
df_pred = all_data_pca[len(training):].reset_index(drop=True)
Y = training['diabetes_mellitus']

# %%
df_train.columns
# Out:
# RangeIndex(start=0, stop=960, step=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train, Y, test_size=0.20, random_state=42,shuffle=True )

# %%
xg_train = xgb.DMatrix(X_train.values, label=y_train)
xg_test = xgb.DMatrix(X_val.values, label=y_val)

# %%
wandb.init(project="wids_2021", sync_tensorboard=True)
config = wandb.config


param = {'subsample': 1.0, 
         'num_leaves': 13, 
         'min_child_weight': 1, 
         'max_depth': 6, 
         'learning_rate': 0.1, 
         'gamma': 1.5, 
         'colsample_bytree': .6,
         'n_estimators':1000,
          'eval_metric':'auc',
          'objective': 'binary:logistic'}

# wandb.config.update(params)

watchlist = [(xg_train, 'train'), (xg_test, 'test')]
num_round = 1000
bst = xgb.train(param, xg_train, num_round, watchlist, callbacks=[wandb.xgboost.wandb_callback()])

# get prediction
pred = bst.predict(xg_test)
# Out:
# wandb: Currently logged in as: mariapaskevich (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.18 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.13<br/>
#                 Syncing run <strong style="color:#cdcd00">rosy-firefly-129</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/mariapaskevich/wids_2021" target="_blank">https://wandb.ai/mariapaskevich/wids_2021</a><br/>
#                 Run page: <a href="https://wandb.ai/mariapaskevich/wids_2021/runs/1lxjuvw6" target="_blank">https://wandb.ai/mariapaskevich/wids_2021/runs/1lxjuvw6</a><br/>
#                 Run data is saved locally in <code>/home/jupyter/wids/wandb/run-20210211_214606-1lxjuvw6</code><br/><br/>
# /opt/conda/lib/python3.7/site-packages/xgboost/training.py:19: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# [21:46:09] WARNING: ../src/learner.cc:541:
# Parameters: { n_estimators, num_leaves } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.75223	test-auc:0.73995
# [1]	train-auc:0.78271	test-auc:0.76701
# [2]	train-auc:0.79158	test-auc:0.77626
# [3]	train-auc:0.79611	test-auc:0.77977
# [4]	train-auc:0.80402	test-auc:0.78749
# [5]	train-auc:0.80726	test-auc:0.78937
# [6]	train-auc:0.80978	test-auc:0.79067
# [7]	train-auc:0.81373	test-auc:0.79353
# [8]	train-auc:0.81630	test-auc:0.79529
# [9]	train-auc:0.81818	test-auc:0.79713
# [10]	train-auc:0.81984	test-auc:0.79828
# [11]	train-auc:0.82199	test-auc:0.80039
# [12]	train-auc:0.82317	test-auc:0.80073
# [13]	train-auc:0.82525	test-auc:0.80220
# [14]	train-auc:0.82645	test-auc:0.80290
# [15]	train-auc:0.82793	test-auc:0.80436
# [16]	train-auc:0.82978	test-auc:0.80545
# [17]	train-auc:0.83130	test-auc:0.80617
# [18]	train-auc:0.83312	test-auc:0.80734
# [19]	train-auc:0.83486	test-auc:0.80849
# [20]	train-auc:0.83659	test-auc:0.80978
# [21]	train-auc:0.83818	test-auc:0.81120
# [22]	train-auc:0.83965	test-auc:0.81197
# [23]	train-auc:0.84138	test-auc:0.81303
# [24]	train-auc:0.84299	test-auc:0.81374
# [25]	train-auc:0.84422	test-auc:0.81451
# [26]	train-auc:0.84574	test-auc:0.81530
# [27]	train-auc:0.84738	test-auc:0.81588
# [28]	train-auc:0.84875	test-auc:0.81673
# [29]	train-auc:0.84962	test-auc:0.81720
# [30]	train-auc:0.85133	test-auc:0.81796
# [31]	train-auc:0.85287	test-auc:0.81876
# [32]	train-auc:0.85404	test-auc:0.81937
# [33]	train-auc:0.85518	test-auc:0.81989
# [34]	train-auc:0.85658	test-auc:0.82075
# [35]	train-auc:0.85765	test-auc:0.82153
# [36]	train-auc:0.85865	test-auc:0.82210
# [37]	train-auc:0.85997	test-auc:0.82264
# [38]	train-auc:0.86120	test-auc:0.82299
# [39]	train-auc:0.86233	test-auc:0.82374
# [40]	train-auc:0.86376	test-auc:0.82467
# [41]	train-auc:0.86450	test-auc:0.82528
# [42]	train-auc:0.86543	test-auc:0.82577
# [43]	train-auc:0.86651	test-auc:0.82628
# [44]	train-auc:0.86728	test-auc:0.82648
# [45]	train-auc:0.86855	test-auc:0.82687
# [46]	train-auc:0.86953	test-auc:0.82755
# [47]	train-auc:0.87047	test-auc:0.82797
# [48]	train-auc:0.87155	test-auc:0.82818
# [49]	train-auc:0.87239	test-auc:0.82859
# [50]	train-auc:0.87311	test-auc:0.82916
# [51]	train-auc:0.87406	test-auc:0.82930
# [52]	train-auc:0.87505	test-auc:0.82991
# [53]	train-auc:0.87557	test-auc:0.83046
# [54]	train-auc:0.87659	test-auc:0.83083
# [55]	train-auc:0.87761	test-auc:0.83123
# [56]	train-auc:0.87861	test-auc:0.83164
# [57]	train-auc:0.87973	test-auc:0.83201
# [58]	train-auc:0.88037	test-auc:0.83245
# [59]	train-auc:0.88132	test-auc:0.83267
# [60]	train-auc:0.88237	test-auc:0.83293
# [61]	train-auc:0.88327	test-auc:0.83322
# [62]	train-auc:0.88414	test-auc:0.83352
# [63]	train-auc:0.88460	test-auc:0.83357
# [64]	train-auc:0.88495	test-auc:0.83391
# [65]	train-auc:0.88589	test-auc:0.83426
# [66]	train-auc:0.88657	test-auc:0.83456
# [67]	train-auc:0.88728	test-auc:0.83478
# [68]	train-auc:0.88807	test-auc:0.83509
# [69]	train-auc:0.88901	test-auc:0.83528
# [70]	train-auc:0.88958	test-auc:0.83557
# [71]	train-auc:0.89027	test-auc:0.83576
# [72]	train-auc:0.89064	test-auc:0.83598
# [73]	train-auc:0.89102	test-auc:0.83607
# [74]	train-auc:0.89163	test-auc:0.83625
# [75]	train-auc:0.89256	test-auc:0.83647
# [76]	train-auc:0.89301	test-auc:0.83670
# [77]	train-auc:0.89366	test-auc:0.83681
# [78]	train-auc:0.89434	test-auc:0.83705
# [79]	train-auc:0.89512	test-auc:0.83723
# [80]	train-auc:0.89569	test-auc:0.83745
# [81]	train-auc:0.89627	test-auc:0.83754
# [82]	train-auc:0.89712	test-auc:0.83769
# [83]	train-auc:0.89771	test-auc:0.83788
# [84]	train-auc:0.89830	test-auc:0.83809
# [85]	train-auc:0.89899	test-auc:0.83836
# [86]	train-auc:0.89932	test-auc:0.83856
# [87]	train-auc:0.89992	test-auc:0.83887
# [88]	train-auc:0.90067	test-auc:0.83905
# [89]	train-auc:0.90113	test-auc:0.83934
# [90]	train-auc:0.90157	test-auc:0.83947
# [91]	train-auc:0.90221	test-auc:0.83976
# [92]	train-auc:0.90276	test-auc:0.83991
# [93]	train-auc:0.90341	test-auc:0.84013
# [94]	train-auc:0.90384	test-auc:0.84025
# [95]	train-auc:0.90464	test-auc:0.84041
# [96]	train-auc:0.90537	test-auc:0.84052
# [97]	train-auc:0.90605	test-auc:0.84073
# [98]	train-auc:0.90676	test-auc:0.84077
# [99]	train-auc:0.90747	test-auc:0.84103
# [100]	train-auc:0.90809	test-auc:0.84109
# [101]	train-auc:0.90847	test-auc:0.84125
# [102]	train-auc:0.90913	test-auc:0.84137
# [103]	train-auc:0.90982	test-auc:0.84151
# [104]	train-auc:0.91014	test-auc:0.84162
# [105]	train-auc:0.91053	test-auc:0.84181
# [106]	train-auc:0.91112	test-auc:0.84191
# [107]	train-auc:0.91181	test-auc:0.84199
# [108]	train-auc:0.91216	test-auc:0.84219
# [109]	train-auc:0.91274	test-auc:0.84235
# [110]	train-auc:0.91299	test-auc:0.84244
# [111]	train-auc:0.91348	test-auc:0.84274
# [112]	train-auc:0.91407	test-auc:0.84273
# [113]	train-auc:0.91446	test-auc:0.84294
# [114]	train-auc:0.91484	test-auc:0.84296
# [115]	train-auc:0.91526	test-auc:0.84305
# [116]	train-auc:0.91549	test-auc:0.84309
# [117]	train-auc:0.91610	test-auc:0.84323
# [118]	train-auc:0.91653	test-auc:0.84336
# [119]	train-auc:0.91690	test-auc:0.84352
# [120]	train-auc:0.91716	test-auc:0.84364
# [121]	train-auc:0.91764	test-auc:0.84377
# [122]	train-auc:0.91806	test-auc:0.84391
# [123]	train-auc:0.91842	test-auc:0.84415
# [124]	train-auc:0.91887	test-auc:0.84421
# [125]	train-auc:0.91958	test-auc:0.84430
# [126]	train-auc:0.92006	test-auc:0.84448
# [127]	train-auc:0.92063	test-auc:0.84460
# [128]	train-auc:0.92100	test-auc:0.84467
# [129]	train-auc:0.92136	test-auc:0.84481
# [130]	train-auc:0.92165	test-auc:0.84487
# [131]	train-auc:0.92176	test-auc:0.84491
# [132]	train-auc:0.92230	test-auc:0.84501
# [133]	train-auc:0.92259	test-auc:0.84508
# [134]	train-auc:0.92305	test-auc:0.84527
# [135]	train-auc:0.92344	test-auc:0.84531
# [136]	train-auc:0.92366	test-auc:0.84541
# [137]	train-auc:0.92414	test-auc:0.84549
# [138]	train-auc:0.92457	test-auc:0.84562
# [139]	train-auc:0.92491	test-auc:0.84570
# [140]	train-auc:0.92517	test-auc:0.84573
# [141]	train-auc:0.92559	test-auc:0.84575
# [142]	train-auc:0.92604	test-auc:0.84577
# [143]	train-auc:0.92624	test-auc:0.84579
# [144]	train-auc:0.92660	test-auc:0.84586
# [145]	train-auc:0.92703	test-auc:0.84595
# [146]	train-auc:0.92752	test-auc:0.84608
# [147]	train-auc:0.92791	test-auc:0.84615
# [148]	train-auc:0.92823	test-auc:0.84624
# [149]	train-auc:0.92837	test-auc:0.84627
# [150]	train-auc:0.92869	test-auc:0.84637
# [151]	train-auc:0.92913	test-auc:0.84638
# [152]	train-auc:0.92931	test-auc:0.84659
# [153]	train-auc:0.92975	test-auc:0.84658
# [154]	train-auc:0.93010	test-auc:0.84666
# [155]	train-auc:0.93056	test-auc:0.84666
# [156]	train-auc:0.93093	test-auc:0.84674
# [157]	train-auc:0.93137	test-auc:0.84683
# [158]	train-auc:0.93161	test-auc:0.84694
# [159]	train-auc:0.93188	test-auc:0.84701
# [160]	train-auc:0.93207	test-auc:0.84704
# [161]	train-auc:0.93220	test-auc:0.84708
# [162]	train-auc:0.93263	test-auc:0.84708
# [163]	train-auc:0.93282	test-auc:0.84715
# [164]	train-auc:0.93326	test-auc:0.84735
# [165]	train-auc:0.93342	test-auc:0.84745
# [166]	train-auc:0.93384	test-auc:0.84739
# [167]	train-auc:0.93417	test-auc:0.84745
# [168]	train-auc:0.93447	test-auc:0.84752
# [169]	train-auc:0.93487	test-auc:0.84756
# [170]	train-auc:0.93514	test-auc:0.84763
# [171]	train-auc:0.93553	test-auc:0.84774
# [172]	train-auc:0.93580	test-auc:0.84771
# [173]	train-auc:0.93603	test-auc:0.84778
# [174]	train-auc:0.93632	test-auc:0.84788
# [175]	train-auc:0.93666	test-auc:0.84789
# [176]	train-auc:0.93688	test-auc:0.84796
# [177]	train-auc:0.93701	test-auc:0.84803
# [178]	train-auc:0.93743	test-auc:0.84810
# [179]	train-auc:0.93768	test-auc:0.84813
# [180]	train-auc:0.93806	test-auc:0.84818
# [181]	train-auc:0.93847	test-auc:0.84817
# [182]	train-auc:0.93870	test-auc:0.84822
# [183]	train-auc:0.93897	test-auc:0.84835
# [184]	train-auc:0.93930	test-auc:0.84834
# [185]	train-auc:0.93952	test-auc:0.84846
# [186]	train-auc:0.93995	test-auc:0.84857
# [187]	train-auc:0.94018	test-auc:0.84862
# [188]	train-auc:0.94047	test-auc:0.84860
# [189]	train-auc:0.94078	test-auc:0.84855
# [190]	train-auc:0.94101	test-auc:0.84859
# [191]	train-auc:0.94133	test-auc:0.84859
# [192]	train-auc:0.94157	test-auc:0.84856
# [193]	train-auc:0.94175	test-auc:0.84865
# [194]	train-auc:0.94209	test-auc:0.84870
# [195]	train-auc:0.94231	test-auc:0.84875
# [196]	train-auc:0.94261	test-auc:0.84872
# [197]	train-auc:0.94283	test-auc:0.84882
# [198]	train-auc:0.94302	test-auc:0.84882
# [199]	train-auc:0.94314	test-auc:0.84882
# [200]	train-auc:0.94338	test-auc:0.84886
# [201]	train-auc:0.94347	test-auc:0.84889
# [202]	train-auc:0.94372	test-auc:0.84900
# [203]	train-auc:0.94389	test-auc:0.84900
# [204]	train-auc:0.94410	test-auc:0.84908
# [205]	train-auc:0.94422	test-auc:0.84907
# [206]	train-auc:0.94449	test-auc:0.84907
# [207]	train-auc:0.94479	test-auc:0.84912
# [208]	train-auc:0.94499	test-auc:0.84922
# [209]	train-auc:0.94512	test-auc:0.84926
# [210]	train-auc:0.94534	test-auc:0.84928
# [211]	train-auc:0.94570	test-auc:0.84928
# [212]	train-auc:0.94596	test-auc:0.84938
# [213]	train-auc:0.94614	test-auc:0.84939
# [214]	train-auc:0.94631	test-auc:0.84935
# [215]	train-auc:0.94641	test-auc:0.84934
# [216]	train-auc:0.94658	test-auc:0.84946
# [217]	train-auc:0.94678	test-auc:0.84940
# [218]	train-auc:0.94696	test-auc:0.84942
# [219]	train-auc:0.94706	test-auc:0.84944
# [220]	train-auc:0.94740	test-auc:0.84950
# [221]	train-auc:0.94748	test-auc:0.84955
# [222]	train-auc:0.94768	test-auc:0.84947
# [223]	train-auc:0.94791	test-auc:0.84951
# [224]	train-auc:0.94795	test-auc:0.84950
# [225]	train-auc:0.94804	test-auc:0.84953
# [226]	train-auc:0.94826	test-auc:0.84951
# [227]	train-auc:0.94847	test-auc:0.84956
# [228]	train-auc:0.94874	test-auc:0.84958
# [229]	train-auc:0.94898	test-auc:0.84962
# [230]	train-auc:0.94931	test-auc:0.84966
# [231]	train-auc:0.94965	test-auc:0.84970
# [232]	train-auc:0.94984	test-auc:0.84974
# [233]	train-auc:0.94996	test-auc:0.84974
# [234]	train-auc:0.95021	test-auc:0.84975
# [235]	train-auc:0.95043	test-auc:0.84973
# [236]	train-auc:0.95074	test-auc:0.84967
# [237]	train-auc:0.95105	test-auc:0.84968
# [238]	train-auc:0.95122	test-auc:0.84966
# [239]	train-auc:0.95132	test-auc:0.84963
# [240]	train-auc:0.95164	test-auc:0.84961
# [241]	train-auc:0.95197	test-auc:0.84979
# [242]	train-auc:0.95202	test-auc:0.84982
# [243]	train-auc:0.95217	test-auc:0.84988
# [244]	train-auc:0.95235	test-auc:0.84989
# [245]	train-auc:0.95242	test-auc:0.85002
# [246]	train-auc:0.95254	test-auc:0.85006
# [247]	train-auc:0.95274	test-auc:0.85007
# [248]	train-auc:0.95301	test-auc:0.85006
# [249]	train-auc:0.95316	test-auc:0.85005
# [250]	train-auc:0.95343	test-auc:0.84999
# [251]	train-auc:0.95381	test-auc:0.84993
# [252]	train-auc:0.95403	test-auc:0.84997
# [253]	train-auc:0.95429	test-auc:0.84995
# [254]	train-auc:0.95441	test-auc:0.84996
# [255]	train-auc:0.95448	test-auc:0.84998
# [256]	train-auc:0.95475	test-auc:0.84999
# [257]	train-auc:0.95480	test-auc:0.84996
# [258]	train-auc:0.95494	test-auc:0.84994
# [259]	train-auc:0.95498	test-auc:0.84999
# [260]	train-auc:0.95509	test-auc:0.84998
# [261]	train-auc:0.95520	test-auc:0.84996
# [262]	train-auc:0.95528	test-auc:0.84991
# [263]	train-auc:0.95541	test-auc:0.84995
# [264]	train-auc:0.95552	test-auc:0.84996
# [265]	train-auc:0.95566	test-auc:0.85001
# [266]	train-auc:0.95583	test-auc:0.85002
# [267]	train-auc:0.95607	test-auc:0.85008
# [268]	train-auc:0.95630	test-auc:0.85006
# [269]	train-auc:0.95656	test-auc:0.85013
# [270]	train-auc:0.95680	test-auc:0.85015
# [271]	train-auc:0.95692	test-auc:0.85010
# [272]	train-auc:0.95720	test-auc:0.85006
# [273]	train-auc:0.95742	test-auc:0.85009
# [274]	train-auc:0.95752	test-auc:0.85009
# [275]	train-auc:0.95764	test-auc:0.85012
# [276]	train-auc:0.95786	test-auc:0.85019
# [277]	train-auc:0.95802	test-auc:0.85014
# [278]	train-auc:0.95810	test-auc:0.85012
# [279]	train-auc:0.95822	test-auc:0.85010
# [280]	train-auc:0.95832	test-auc:0.85008
# [281]	train-auc:0.95849	test-auc:0.85008
# [282]	train-auc:0.95866	test-auc:0.85007
# [283]	train-auc:0.95880	test-auc:0.85004
# [284]	train-auc:0.95887	test-auc:0.85006
# [285]	train-auc:0.95898	test-auc:0.85003
# [286]	train-auc:0.95906	test-auc:0.85009
# [287]	train-auc:0.95919	test-auc:0.85016
# [288]	train-auc:0.95928	test-auc:0.85020
# [289]	train-auc:0.95933	test-auc:0.85021
# [290]	train-auc:0.95953	test-auc:0.85019
# [291]	train-auc:0.95964	test-auc:0.85017
# [292]	train-auc:0.95992	test-auc:0.85023
# [293]	train-auc:0.96015	test-auc:0.85022
# [294]	train-auc:0.96028	test-auc:0.85024
# [295]	train-auc:0.96039	test-auc:0.85027
# [296]	train-auc:0.96051	test-auc:0.85036
# [297]	train-auc:0.96070	test-auc:0.85038
# [298]	train-auc:0.96102	test-auc:0.85034
# [299]	train-auc:0.96118	test-auc:0.85031
# [300]	train-auc:0.96134	test-auc:0.85035
# [301]	train-auc:0.96154	test-auc:0.85043
# [302]	train-auc:0.96158	test-auc:0.85045
# [303]	train-auc:0.96174	test-auc:0.85046
# [304]	train-auc:0.96181	test-auc:0.85045
# [305]	train-auc:0.96199	test-auc:0.85049
# [306]	train-auc:0.96203	test-auc:0.85048
# [307]	train-auc:0.96213	test-auc:0.85044
# [308]	train-auc:0.96228	test-auc:0.85042
# [309]	train-auc:0.96231	test-auc:0.85043
# [310]	train-auc:0.96238	test-auc:0.85040
# [311]	train-auc:0.96256	test-auc:0.85039
# [312]	train-auc:0.96267	test-auc:0.85037
# [313]	train-auc:0.96281	test-auc:0.85037
# [314]	train-auc:0.96283	test-auc:0.85039
# [315]	train-auc:0.96298	test-auc:0.85047
# [316]	train-auc:0.96312	test-auc:0.85053
# [317]	train-auc:0.96323	test-auc:0.85050
# [318]	train-auc:0.96343	test-auc:0.85057
# [319]	train-auc:0.96352	test-auc:0.85060
# [320]	train-auc:0.96373	test-auc:0.85060
# [321]	train-auc:0.96376	test-auc:0.85062
# [322]	train-auc:0.96390	test-auc:0.85065
# [323]	train-auc:0.96396	test-auc:0.85064
# [324]	train-auc:0.96427	test-auc:0.85069
# [325]	train-auc:0.96436	test-auc:0.85073
# [326]	train-auc:0.96446	test-auc:0.85071
# [327]	train-auc:0.96463	test-auc:0.85074
# [328]	train-auc:0.96488	test-auc:0.85082
# [329]	train-auc:0.96505	test-auc:0.85086
# [330]	train-auc:0.96510	test-auc:0.85085
# [331]	train-auc:0.96519	test-auc:0.85085
# [332]	train-auc:0.96527	test-auc:0.85081
# [333]	train-auc:0.96545	test-auc:0.85092
# [334]	train-auc:0.96549	test-auc:0.85093
# [335]	train-auc:0.96560	test-auc:0.85093
# [336]	train-auc:0.96581	test-auc:0.85097
# [337]	train-auc:0.96592	test-auc:0.85101
# [338]	train-auc:0.96601	test-auc:0.85103
# [339]	train-auc:0.96628	test-auc:0.85107
# [340]	train-auc:0.96631	test-auc:0.85107
# [341]	train-auc:0.96651	test-auc:0.85113
# [342]	train-auc:0.96666	test-auc:0.85112
# [343]	train-auc:0.96678	test-auc:0.85105
# [344]	train-auc:0.96690	test-auc:0.85106
# [345]	train-auc:0.96705	test-auc:0.85118
# [346]	train-auc:0.96727	test-auc:0.85112
# [347]	train-auc:0.96736	test-auc:0.85112
# [348]	train-auc:0.96758	test-auc:0.85111
# [349]	train-auc:0.96773	test-auc:0.85114
# [350]	train-auc:0.96790	test-auc:0.85111
# [351]	train-auc:0.96795	test-auc:0.85118
# [352]	train-auc:0.96799	test-auc:0.85116
# [353]	train-auc:0.96807	test-auc:0.85117
# [354]	train-auc:0.96814	test-auc:0.85116
# [355]	train-auc:0.96819	test-auc:0.85116
# [356]	train-auc:0.96826	test-auc:0.85118
# [357]	train-auc:0.96835	test-auc:0.85124
# [358]	train-auc:0.96847	test-auc:0.85120
# [359]	train-auc:0.96860	test-auc:0.85119
# [360]	train-auc:0.96873	test-auc:0.85116
# [361]	train-auc:0.96896	test-auc:0.85117
# [362]	train-auc:0.96916	test-auc:0.85113
# [363]	train-auc:0.96934	test-auc:0.85109
# [364]	train-auc:0.96943	test-auc:0.85109
# [365]	train-auc:0.96953	test-auc:0.85108
# [366]	train-auc:0.96962	test-auc:0.85106
# [367]	train-auc:0.96980	test-auc:0.85111
# [368]	train-auc:0.96996	test-auc:0.85104
# [369]	train-auc:0.97012	test-auc:0.85108
# [370]	train-auc:0.97028	test-auc:0.85108
# [371]	train-auc:0.97036	test-auc:0.85108
# [372]	train-auc:0.97051	test-auc:0.85106
# [373]	train-auc:0.97065	test-auc:0.85113
# [374]	train-auc:0.97086	test-auc:0.85114
# [375]	train-auc:0.97100	test-auc:0.85118
# [376]	train-auc:0.97119	test-auc:0.85115
# [377]	train-auc:0.97131	test-auc:0.85115
# [378]	train-auc:0.97139	test-auc:0.85118
# [379]	train-auc:0.97143	test-auc:0.85118
# [380]	train-auc:0.97152	test-auc:0.85119
# [381]	train-auc:0.97161	test-auc:0.85121
# [382]	train-auc:0.97168	test-auc:0.85125
# [383]	train-auc:0.97174	test-auc:0.85121
# [384]	train-auc:0.97186	test-auc:0.85120
# [385]	train-auc:0.97190	test-auc:0.85119
# [386]	train-auc:0.97205	test-auc:0.85114
# [387]	train-auc:0.97220	test-auc:0.85111
# [388]	train-auc:0.97230	test-auc:0.85112
# [389]	train-auc:0.97239	test-auc:0.85113
# [390]	train-auc:0.97249	test-auc:0.85115
# [391]	train-auc:0.97252	test-auc:0.85115
# [392]	train-auc:0.97258	test-auc:0.85123
# [393]	train-auc:0.97263	test-auc:0.85126
# [394]	train-auc:0.97268	test-auc:0.85127
# [395]	train-auc:0.97278	test-auc:0.85130
# [396]	train-auc:0.97296	test-auc:0.85127
# [397]	train-auc:0.97308	test-auc:0.85123
# [398]	train-auc:0.97315	test-auc:0.85121
# [399]	train-auc:0.97323	test-auc:0.85121
# [400]	train-auc:0.97330	test-auc:0.85122
# [401]	train-auc:0.97336	test-auc:0.85121
# [402]	train-auc:0.97350	test-auc:0.85122
# [403]	train-auc:0.97361	test-auc:0.85121
# [404]	train-auc:0.97366	test-auc:0.85121
# [405]	train-auc:0.97384	test-auc:0.85119
# [406]	train-auc:0.97397	test-auc:0.85119
# [407]	train-auc:0.97400	test-auc:0.85121
# [408]	train-auc:0.97403	test-auc:0.85120
# [409]	train-auc:0.97414	test-auc:0.85120
# [410]	train-auc:0.97427	test-auc:0.85125
# [411]	train-auc:0.97439	test-auc:0.85124
# [412]	train-auc:0.97449	test-auc:0.85125
# [413]	train-auc:0.97469	test-auc:0.85122
# [414]	train-auc:0.97472	test-auc:0.85122
# [415]	train-auc:0.97479	test-auc:0.85119
# [416]	train-auc:0.97493	test-auc:0.85123
# [417]	train-auc:0.97505	test-auc:0.85128
# [418]	train-auc:0.97511	test-auc:0.85126
# [419]	train-auc:0.97523	test-auc:0.85127
# [420]	train-auc:0.97532	test-auc:0.85127
# [421]	train-auc:0.97534	test-auc:0.85123
# [422]	train-auc:0.97538	test-auc:0.85121
# [423]	train-auc:0.97542	test-auc:0.85124
# [424]	train-auc:0.97548	test-auc:0.85125
# [425]	train-auc:0.97551	test-auc:0.85129
# [426]	train-auc:0.97556	test-auc:0.85130
# [427]	train-auc:0.97567	test-auc:0.85126
# [428]	train-auc:0.97572	test-auc:0.85125
# [429]	train-auc:0.97578	test-auc:0.85128
# [430]	train-auc:0.97593	test-auc:0.85130
# [431]	train-auc:0.97601	test-auc:0.85133
# [432]	train-auc:0.97618	test-auc:0.85132
# [433]	train-auc:0.97632	test-auc:0.85140
# [434]	train-auc:0.97651	test-auc:0.85143
# [435]	train-auc:0.97663	test-auc:0.85146
# [436]	train-auc:0.97678	test-auc:0.85146
# [437]	train-auc:0.97689	test-auc:0.85145
# [438]	train-auc:0.97705	test-auc:0.85145
# [439]	train-auc:0.97714	test-auc:0.85139
# [440]	train-auc:0.97732	test-auc:0.85133
# [441]	train-auc:0.97741	test-auc:0.85136
# [442]	train-auc:0.97754	test-auc:0.85139
# [443]	train-auc:0.97764	test-auc:0.85141
# [444]	train-auc:0.97772	test-auc:0.85145
# [445]	train-auc:0.97778	test-auc:0.85147
# [446]	train-auc:0.97791	test-auc:0.85144
# [447]	train-auc:0.97800	test-auc:0.85146
# [448]	train-auc:0.97806	test-auc:0.85148
# [449]	train-auc:0.97813	test-auc:0.85147
# [450]	train-auc:0.97814	test-auc:0.85147
# [451]	train-auc:0.97816	test-auc:0.85147
# [452]	train-auc:0.97818	test-auc:0.85146
# [453]	train-auc:0.97829	test-auc:0.85145
# [454]	train-auc:0.97846	test-auc:0.85151
# [455]	train-auc:0.97848	test-auc:0.85149
# [456]	train-auc:0.97864	test-auc:0.85144
# [457]	train-auc:0.97878	test-auc:0.85147
# [458]	train-auc:0.97884	test-auc:0.85147
# [459]	train-auc:0.97893	test-auc:0.85147
# [460]	train-auc:0.97904	test-auc:0.85144
# [461]	train-auc:0.97908	test-auc:0.85144
# [462]	train-auc:0.97912	test-auc:0.85145
# [463]	train-auc:0.97919	test-auc:0.85145
# [464]	train-auc:0.97928	test-auc:0.85145
# [465]	train-auc:0.97933	test-auc:0.85146
# [466]	train-auc:0.97945	test-auc:0.85149
# [467]	train-auc:0.97962	test-auc:0.85151
# [468]	train-auc:0.97975	test-auc:0.85156
# [469]	train-auc:0.97982	test-auc:0.85151
# [470]	train-auc:0.97986	test-auc:0.85152
# [471]	train-auc:0.97994	test-auc:0.85151
# [472]	train-auc:0.98009	test-auc:0.85156
# [473]	train-auc:0.98019	test-auc:0.85161
# [474]	train-auc:0.98028	test-auc:0.85160
# [475]	train-auc:0.98032	test-auc:0.85159
# [476]	train-auc:0.98037	test-auc:0.85160
# [477]	train-auc:0.98042	test-auc:0.85159
# [478]	train-auc:0.98052	test-auc:0.85160
# [479]	train-auc:0.98065	test-auc:0.85165
# [480]	train-auc:0.98076	test-auc:0.85171
# [481]	train-auc:0.98083	test-auc:0.85166
# [482]	train-auc:0.98091	test-auc:0.85164
# [483]	train-auc:0.98099	test-auc:0.85162
# [484]	train-auc:0.98104	test-auc:0.85162
# [485]	train-auc:0.98117	test-auc:0.85163
# [486]	train-auc:0.98128	test-auc:0.85162
# [487]	train-auc:0.98135	test-auc:0.85163
# [488]	train-auc:0.98147	test-auc:0.85163
# [489]	train-auc:0.98167	test-auc:0.85167
# [490]	train-auc:0.98176	test-auc:0.85166
# [491]	train-auc:0.98193	test-auc:0.85167
# [492]	train-auc:0.98195	test-auc:0.85169
# [493]	train-auc:0.98197	test-auc:0.85169
# [494]	train-auc:0.98206	test-auc:0.85168
# [495]	train-auc:0.98214	test-auc:0.85170
# [496]	train-auc:0.98217	test-auc:0.85171
# [497]	train-auc:0.98220	test-auc:0.85166
# [498]	train-auc:0.98231	test-auc:0.85166
# [499]	train-auc:0.98244	test-auc:0.85165
# [500]	train-auc:0.98250	test-auc:0.85166
# [501]	train-auc:0.98258	test-auc:0.85165
# [502]	train-auc:0.98268	test-auc:0.85165
# [503]	train-auc:0.98278	test-auc:0.85164
# [504]	train-auc:0.98281	test-auc:0.85159
# [505]	train-auc:0.98283	test-auc:0.85160
# [506]	train-auc:0.98291	test-auc:0.85165
# [507]	train-auc:0.98304	test-auc:0.85173
# [508]	train-auc:0.98311	test-auc:0.85173
# [509]	train-auc:0.98319	test-auc:0.85167
# [510]	train-auc:0.98326	test-auc:0.85171
# [511]	train-auc:0.98334	test-auc:0.85180
# [512]	train-auc:0.98345	test-auc:0.85179
# [513]	train-auc:0.98349	test-auc:0.85177
# [514]	train-auc:0.98354	test-auc:0.85177
# [515]	train-auc:0.98364	test-auc:0.85182
# [516]	train-auc:0.98369	test-auc:0.85173
# [517]	train-auc:0.98378	test-auc:0.85179
# [518]	train-auc:0.98383	test-auc:0.85179
# [519]	train-auc:0.98388	test-auc:0.85181
# [520]	train-auc:0.98394	test-auc:0.85182
# [521]	train-auc:0.98399	test-auc:0.85183
# [522]	train-auc:0.98404	test-auc:0.85183
# [523]	train-auc:0.98409	test-auc:0.85182
# [524]	train-auc:0.98418	test-auc:0.85190
# [525]	train-auc:0.98427	test-auc:0.85192
# [526]	train-auc:0.98434	test-auc:0.85191
# [527]	train-auc:0.98446	test-auc:0.85190
# [528]	train-auc:0.98459	test-auc:0.85191
# [529]	train-auc:0.98472	test-auc:0.85187
# [530]	train-auc:0.98480	test-auc:0.85185
# [531]	train-auc:0.98490	test-auc:0.85187
# [532]	train-auc:0.98503	test-auc:0.85186
# [533]	train-auc:0.98508	test-auc:0.85186
# [534]	train-auc:0.98515	test-auc:0.85191
# [535]	train-auc:0.98529	test-auc:0.85191
# [536]	train-auc:0.98540	test-auc:0.85196
# [537]	train-auc:0.98548	test-auc:0.85194
# [538]	train-auc:0.98558	test-auc:0.85193
# [539]	train-auc:0.98571	test-auc:0.85196
# [540]	train-auc:0.98575	test-auc:0.85192
# [541]	train-auc:0.98589	test-auc:0.85187
# [542]	train-auc:0.98599	test-auc:0.85187
# [543]	train-auc:0.98608	test-auc:0.85187
# [544]	train-auc:0.98613	test-auc:0.85188
# [545]	train-auc:0.98621	test-auc:0.85191
# [546]	train-auc:0.98623	test-auc:0.85188
# [547]	train-auc:0.98630	test-auc:0.85187
# [548]	train-auc:0.98642	test-auc:0.85186
# [549]	train-auc:0.98653	test-auc:0.85189
# [550]	train-auc:0.98659	test-auc:0.85185
# [551]	train-auc:0.98661	test-auc:0.85185
# [552]	train-auc:0.98664	test-auc:0.85184
# [553]	train-auc:0.98668	test-auc:0.85186
# [554]	train-auc:0.98671	test-auc:0.85191
# [555]	train-auc:0.98684	test-auc:0.85188
# [556]	train-auc:0.98692	test-auc:0.85182
# [557]	train-auc:0.98697	test-auc:0.85183
# [558]	train-auc:0.98705	test-auc:0.85183
# [559]	train-auc:0.98708	test-auc:0.85182
# [560]	train-auc:0.98711	test-auc:0.85183
# [561]	train-auc:0.98725	test-auc:0.85177
# [562]	train-auc:0.98735	test-auc:0.85193
# [563]	train-auc:0.98739	test-auc:0.85197
# [564]	train-auc:0.98743	test-auc:0.85196
# [565]	train-auc:0.98748	test-auc:0.85200
# [566]	train-auc:0.98752	test-auc:0.85203
# [567]	train-auc:0.98755	test-auc:0.85206
# [568]	train-auc:0.98757	test-auc:0.85207
# [569]	train-auc:0.98768	test-auc:0.85205
# [570]	train-auc:0.98772	test-auc:0.85208
# [571]	train-auc:0.98779	test-auc:0.85205
# [572]	train-auc:0.98784	test-auc:0.85204
# [573]	train-auc:0.98788	test-auc:0.85204
# [574]	train-auc:0.98797	test-auc:0.85198
# [575]	train-auc:0.98807	test-auc:0.85196
# [576]	train-auc:0.98812	test-auc:0.85195
# [577]	train-auc:0.98816	test-auc:0.85197
# [578]	train-auc:0.98821	test-auc:0.85198
# [579]	train-auc:0.98829	test-auc:0.85199
# [580]	train-auc:0.98837	test-auc:0.85201
# [581]	train-auc:0.98842	test-auc:0.85203
# [582]	train-auc:0.98848	test-auc:0.85205
# [583]	train-auc:0.98853	test-auc:0.85201
# [584]	train-auc:0.98857	test-auc:0.85201
# [585]	train-auc:0.98863	test-auc:0.85202
# [586]	train-auc:0.98866	test-auc:0.85200
# [587]	train-auc:0.98873	test-auc:0.85195
# [588]	train-auc:0.98876	test-auc:0.85193
# [589]	train-auc:0.98880	test-auc:0.85195
# [590]	train-auc:0.98882	test-auc:0.85194
# [591]	train-auc:0.98891	test-auc:0.85195
# [592]	train-auc:0.98892	test-auc:0.85196
# [593]	train-auc:0.98894	test-auc:0.85198
# [594]	train-auc:0.98902	test-auc:0.85194
# [595]	train-auc:0.98908	test-auc:0.85188
# [596]	train-auc:0.98914	test-auc:0.85193
# [597]	train-auc:0.98917	test-auc:0.85192
# [598]	train-auc:0.98922	test-auc:0.85193
# [599]	train-auc:0.98928	test-auc:0.85191
# [600]	train-auc:0.98935	test-auc:0.85187
# [601]	train-auc:0.98945	test-auc:0.85180
# [602]	train-auc:0.98953	test-auc:0.85177
# [603]	train-auc:0.98959	test-auc:0.85185
# [604]	train-auc:0.98966	test-auc:0.85183
# [605]	train-auc:0.98970	test-auc:0.85181
# [606]	train-auc:0.98976	test-auc:0.85181
# [607]	train-auc:0.98981	test-auc:0.85178
# [608]	train-auc:0.98985	test-auc:0.85179
# [609]	train-auc:0.98989	test-auc:0.85177
# [610]	train-auc:0.98995	test-auc:0.85178
# [611]	train-auc:0.99000	test-auc:0.85179
# [612]	train-auc:0.99002	test-auc:0.85180
# [613]	train-auc:0.99006	test-auc:0.85185
# [614]	train-auc:0.99014	test-auc:0.85189
# [615]	train-auc:0.99021	test-auc:0.85194
# [616]	train-auc:0.99028	test-auc:0.85195
# [617]	train-auc:0.99031	test-auc:0.85195
# [618]	train-auc:0.99039	test-auc:0.85193
# [619]	train-auc:0.99040	test-auc:0.85193
# [620]	train-auc:0.99042	test-auc:0.85195
# [621]	train-auc:0.99049	test-auc:0.85193
# [622]	train-auc:0.99057	test-auc:0.85196
# [623]	train-auc:0.99063	test-auc:0.85192
# [624]	train-auc:0.99071	test-auc:0.85194
# [625]	train-auc:0.99073	test-auc:0.85194
# [626]	train-auc:0.99080	test-auc:0.85195
# [627]	train-auc:0.99082	test-auc:0.85195
# [628]	train-auc:0.99087	test-auc:0.85198
# [629]	train-auc:0.99093	test-auc:0.85199
# [630]	train-auc:0.99098	test-auc:0.85200
# [631]	train-auc:0.99096	test-auc:0.85207
# [632]	train-auc:0.99098	test-auc:0.85205
# [633]	train-auc:0.99103	test-auc:0.85209
# [634]	train-auc:0.99108	test-auc:0.85204
# [635]	train-auc:0.99112	test-auc:0.85204
# [636]	train-auc:0.99113	test-auc:0.85205
# [637]	train-auc:0.99118	test-auc:0.85208
# [638]	train-auc:0.99123	test-auc:0.85205
# [639]	train-auc:0.99124	test-auc:0.85204
# [640]	train-auc:0.99126	test-auc:0.85205
# [641]	train-auc:0.99129	test-auc:0.85203
# [642]	train-auc:0.99138	test-auc:0.85201
# [643]	train-auc:0.99144	test-auc:0.85193
# [644]	train-auc:0.99148	test-auc:0.85193
# [645]	train-auc:0.99149	test-auc:0.85192
# [646]	train-auc:0.99151	test-auc:0.85195
# [647]	train-auc:0.99152	test-auc:0.85201
# [648]	train-auc:0.99156	test-auc:0.85201
# [649]	train-auc:0.99162	test-auc:0.85198
# [650]	train-auc:0.99164	test-auc:0.85201
# [651]	train-auc:0.99166	test-auc:0.85197
# [652]	train-auc:0.99169	test-auc:0.85196
# [653]	train-auc:0.99171	test-auc:0.85190
# [654]	train-auc:0.99171	test-auc:0.85192
# [655]	train-auc:0.99172	test-auc:0.85195
# [656]	train-auc:0.99173	test-auc:0.85195
# [657]	train-auc:0.99174	test-auc:0.85194
# [658]	train-auc:0.99178	test-auc:0.85201
# [659]	train-auc:0.99180	test-auc:0.85201
# [660]	train-auc:0.99183	test-auc:0.85204
# [661]	train-auc:0.99190	test-auc:0.85205
# [662]	train-auc:0.99195	test-auc:0.85204
# [663]	train-auc:0.99201	test-auc:0.85205
# [664]	train-auc:0.99204	test-auc:0.85207
# [665]	train-auc:0.99207	test-auc:0.85206
# [666]	train-auc:0.99215	test-auc:0.85204
# [667]	train-auc:0.99221	test-auc:0.85204
# [668]	train-auc:0.99223	test-auc:0.85203
# [669]	train-auc:0.99226	test-auc:0.85203
# [670]	train-auc:0.99235	test-auc:0.85198
# [671]	train-auc:0.99240	test-auc:0.85198
# [672]	train-auc:0.99244	test-auc:0.85197
# [673]	train-auc:0.99247	test-auc:0.85194
# [674]	train-auc:0.99250	test-auc:0.85195
# [675]	train-auc:0.99252	test-auc:0.85194
# [676]	train-auc:0.99257	test-auc:0.85199
# [677]	train-auc:0.99259	test-auc:0.85196
# [678]	train-auc:0.99263	test-auc:0.85197
# [679]	train-auc:0.99265	test-auc:0.85197
# [680]	train-auc:0.99266	test-auc:0.85198
# [681]	train-auc:0.99273	test-auc:0.85196
# [682]	train-auc:0.99276	test-auc:0.85193
# [683]	train-auc:0.99278	test-auc:0.85193
# [684]	train-auc:0.99280	test-auc:0.85191
# [685]	train-auc:0.99282	test-auc:0.85196
# [686]	train-auc:0.99287	test-auc:0.85201
# [687]	train-auc:0.99295	test-auc:0.85203
# [688]	train-auc:0.99295	test-auc:0.85209
# [689]	train-auc:0.99300	test-auc:0.85212
# [690]	train-auc:0.99300	test-auc:0.85209
# [691]	train-auc:0.99302	test-auc:0.85210
# [692]	train-auc:0.99305	test-auc:0.85208
# [693]	train-auc:0.99308	test-auc:0.85211
# [694]	train-auc:0.99314	test-auc:0.85213
# [695]	train-auc:0.99316	test-auc:0.85213
# [696]	train-auc:0.99317	test-auc:0.85212
# [697]	train-auc:0.99321	test-auc:0.85211
# [698]	train-auc:0.99324	test-auc:0.85212
# [699]	train-auc:0.99327	test-auc:0.85211
# [700]	train-auc:0.99327	test-auc:0.85210
# [701]	train-auc:0.99330	test-auc:0.85209
# [702]	train-auc:0.99335	test-auc:0.85208
# [703]	train-auc:0.99339	test-auc:0.85211
# [704]	train-auc:0.99342	test-auc:0.85211
# [705]	train-auc:0.99346	test-auc:0.85217
# [706]	train-auc:0.99352	test-auc:0.85218
# [707]	train-auc:0.99355	test-auc:0.85221
# [708]	train-auc:0.99360	test-auc:0.85214
# [709]	train-auc:0.99361	test-auc:0.85215
# [710]	train-auc:0.99365	test-auc:0.85211
# [711]	train-auc:0.99369	test-auc:0.85212
# [712]	train-auc:0.99372	test-auc:0.85210
# [713]	train-auc:0.99377	test-auc:0.85206
# [714]	train-auc:0.99380	test-auc:0.85208
# [715]	train-auc:0.99381	test-auc:0.85207
# [716]	train-auc:0.99382	test-auc:0.85205
# [717]	train-auc:0.99383	test-auc:0.85204
# [718]	train-auc:0.99385	test-auc:0.85207
# [719]	train-auc:0.99388	test-auc:0.85210
# [720]	train-auc:0.99394	test-auc:0.85210
# [721]	train-auc:0.99398	test-auc:0.85208
# [722]	train-auc:0.99403	test-auc:0.85207
# [723]	train-auc:0.99407	test-auc:0.85206
# [724]	train-auc:0.99409	test-auc:0.85203
# [725]	train-auc:0.99410	test-auc:0.85202
# [726]	train-auc:0.99410	test-auc:0.85201
# [727]	train-auc:0.99414	test-auc:0.85200
# [728]	train-auc:0.99414	test-auc:0.85200
# [729]	train-auc:0.99417	test-auc:0.85199
# [730]	train-auc:0.99418	test-auc:0.85200
# [731]	train-auc:0.99421	test-auc:0.85201
# [732]	train-auc:0.99423	test-auc:0.85200
# [733]	train-auc:0.99424	test-auc:0.85200
# [734]	train-auc:0.99430	test-auc:0.85200
# [735]	train-auc:0.99435	test-auc:0.85198
# [736]	train-auc:0.99439	test-auc:0.85201
# [737]	train-auc:0.99442	test-auc:0.85206
# [738]	train-auc:0.99445	test-auc:0.85203
# [739]	train-auc:0.99448	test-auc:0.85209
# [740]	train-auc:0.99453	test-auc:0.85211
# [741]	train-auc:0.99454	test-auc:0.85211
# [742]	train-auc:0.99456	test-auc:0.85213
# [743]	train-auc:0.99458	test-auc:0.85211
# [744]	train-auc:0.99462	test-auc:0.85210
# [745]	train-auc:0.99464	test-auc:0.85216
# [746]	train-auc:0.99466	test-auc:0.85215
# [747]	train-auc:0.99468	test-auc:0.85217
# [748]	train-auc:0.99474	test-auc:0.85212
# [749]	train-auc:0.99477	test-auc:0.85213
# [750]	train-auc:0.99479	test-auc:0.85218
# [751]	train-auc:0.99480	test-auc:0.85220
# [752]	train-auc:0.99481	test-auc:0.85220
# [753]	train-auc:0.99482	test-auc:0.85217
# [754]	train-auc:0.99484	test-auc:0.85217
# [755]	train-auc:0.99486	test-auc:0.85218
# [756]	train-auc:0.99489	test-auc:0.85213
# [757]	train-auc:0.99491	test-auc:0.85215
# [758]	train-auc:0.99491	test-auc:0.85214
# [759]	train-auc:0.99495	test-auc:0.85215
# [760]	train-auc:0.99500	test-auc:0.85214
# [761]	train-auc:0.99504	test-auc:0.85209
# [762]	train-auc:0.99509	test-auc:0.85206
# [763]	train-auc:0.99511	test-auc:0.85207
# [764]	train-auc:0.99512	test-auc:0.85217
# [765]	train-auc:0.99517	test-auc:0.85208
# [766]	train-auc:0.99518	test-auc:0.85212
# [767]	train-auc:0.99520	test-auc:0.85211
# [768]	train-auc:0.99524	test-auc:0.85215
# [769]	train-auc:0.99530	test-auc:0.85216
# [770]	train-auc:0.99533	test-auc:0.85213
# [771]	train-auc:0.99537	test-auc:0.85214
# [772]	train-auc:0.99541	test-auc:0.85215
# [773]	train-auc:0.99546	test-auc:0.85212
# [774]	train-auc:0.99550	test-auc:0.85205
# [775]	train-auc:0.99553	test-auc:0.85203
# [776]	train-auc:0.99553	test-auc:0.85203
# [777]	train-auc:0.99557	test-auc:0.85201
# [778]	train-auc:0.99558	test-auc:0.85196
# [779]	train-auc:0.99560	test-auc:0.85194
# [780]	train-auc:0.99565	test-auc:0.85191
# [781]	train-auc:0.99567	test-auc:0.85189
# [782]	train-auc:0.99570	test-auc:0.85184
# [783]	train-auc:0.99571	test-auc:0.85185
# [784]	train-auc:0.99573	test-auc:0.85191
# [785]	train-auc:0.99574	test-auc:0.85193
# [786]	train-auc:0.99576	test-auc:0.85191
# [787]	train-auc:0.99578	test-auc:0.85190
# [788]	train-auc:0.99582	test-auc:0.85189
# [789]	train-auc:0.99582	test-auc:0.85187
# [790]	train-auc:0.99584	test-auc:0.85185
# [791]	train-auc:0.99586	test-auc:0.85191
# [792]	train-auc:0.99589	test-auc:0.85187
# [793]	train-auc:0.99593	test-auc:0.85190
# [794]	train-auc:0.99594	test-auc:0.85185
# [795]	train-auc:0.99598	test-auc:0.85184
# [796]	train-auc:0.99599	test-auc:0.85182
# [797]	train-auc:0.99600	test-auc:0.85183
# [798]	train-auc:0.99602	test-auc:0.85184
# [799]	train-auc:0.99606	test-auc:0.85182
# [800]	train-auc:0.99607	test-auc:0.85182
# [801]	train-auc:0.99608	test-auc:0.85175
# [802]	train-auc:0.99611	test-auc:0.85178
# [803]	train-auc:0.99613	test-auc:0.85179
# [804]	train-auc:0.99614	test-auc:0.85179
# [805]	train-auc:0.99619	test-auc:0.85176
# [806]	train-auc:0.99622	test-auc:0.85176
# [807]	train-auc:0.99625	test-auc:0.85168
# [808]	train-auc:0.99629	test-auc:0.85164
# [809]	train-auc:0.99631	test-auc:0.85162
# [810]	train-auc:0.99633	test-auc:0.85171
# [811]	train-auc:0.99635	test-auc:0.85171
# [812]	train-auc:0.99635	test-auc:0.85170
# [813]	train-auc:0.99639	test-auc:0.85167
# [814]	train-auc:0.99639	test-auc:0.85169
# [815]	train-auc:0.99644	test-auc:0.85165
# [816]	train-auc:0.99645	test-auc:0.85162
# [817]	train-auc:0.99646	test-auc:0.85159
# [818]	train-auc:0.99648	test-auc:0.85160
# [819]	train-auc:0.99649	test-auc:0.85161
# [820]	train-auc:0.99652	test-auc:0.85159
# [821]	train-auc:0.99656	test-auc:0.85156
# [822]	train-auc:0.99657	test-auc:0.85159
# [823]	train-auc:0.99660	test-auc:0.85155
# [824]	train-auc:0.99664	test-auc:0.85155
# [825]	train-auc:0.99667	test-auc:0.85155
# [826]	train-auc:0.99668	test-auc:0.85151
# [827]	train-auc:0.99672	test-auc:0.85150
# [828]	train-auc:0.99674	test-auc:0.85150
# [829]	train-auc:0.99676	test-auc:0.85149
# [830]	train-auc:0.99677	test-auc:0.85151
# [831]	train-auc:0.99680	test-auc:0.85154
# [832]	train-auc:0.99680	test-auc:0.85154
# [833]	train-auc:0.99682	test-auc:0.85154
# [834]	train-auc:0.99682	test-auc:0.85153
# [835]	train-auc:0.99683	test-auc:0.85154
# [836]	train-auc:0.99685	test-auc:0.85151
# [837]	train-auc:0.99685	test-auc:0.85150
# [838]	train-auc:0.99686	test-auc:0.85147
# [839]	train-auc:0.99687	test-auc:0.85146
# [840]	train-auc:0.99690	test-auc:0.85149
# [841]	train-auc:0.99693	test-auc:0.85148
# [842]	train-auc:0.99696	test-auc:0.85151
# [843]	train-auc:0.99699	test-auc:0.85153
# [844]	train-auc:0.99701	test-auc:0.85151
# [845]	train-auc:0.99703	test-auc:0.85151
# [846]	train-auc:0.99707	test-auc:0.85148
# [847]	train-auc:0.99709	test-auc:0.85146
# [848]	train-auc:0.99713	test-auc:0.85152
# [849]	train-auc:0.99714	test-auc:0.85153
# [850]	train-auc:0.99716	test-auc:0.85150
# [851]	train-auc:0.99720	test-auc:0.85161
# [852]	train-auc:0.99723	test-auc:0.85157
# [853]	train-auc:0.99724	test-auc:0.85160
# [854]	train-auc:0.99726	test-auc:0.85159
# [855]	train-auc:0.99727	test-auc:0.85159
# [856]	train-auc:0.99728	test-auc:0.85158
# [857]	train-auc:0.99731	test-auc:0.85158
# [858]	train-auc:0.99732	test-auc:0.85158
# [859]	train-auc:0.99733	test-auc:0.85159
# [860]	train-auc:0.99737	test-auc:0.85163
# [861]	train-auc:0.99740	test-auc:0.85156
# [862]	train-auc:0.99744	test-auc:0.85152
# [863]	train-auc:0.99746	test-auc:0.85153
# [864]	train-auc:0.99748	test-auc:0.85156
# [865]	train-auc:0.99751	test-auc:0.85162
# [866]	train-auc:0.99753	test-auc:0.85162
# [867]	train-auc:0.99755	test-auc:0.85161
# [868]	train-auc:0.99757	test-auc:0.85157
# [869]	train-auc:0.99760	test-auc:0.85156
# [870]	train-auc:0.99762	test-auc:0.85156
# [871]	train-auc:0.99763	test-auc:0.85152
# [872]	train-auc:0.99767	test-auc:0.85153
# [873]	train-auc:0.99767	test-auc:0.85150
# [874]	train-auc:0.99768	test-auc:0.85151
# [875]	train-auc:0.99769	test-auc:0.85148
# [876]	train-auc:0.99772	test-auc:0.85150
# [877]	train-auc:0.99774	test-auc:0.85149
# [878]	train-auc:0.99776	test-auc:0.85152
# [879]	train-auc:0.99777	test-auc:0.85156
# [880]	train-auc:0.99778	test-auc:0.85160
# [881]	train-auc:0.99780	test-auc:0.85163
# [882]	train-auc:0.99782	test-auc:0.85160
# [883]	train-auc:0.99784	test-auc:0.85158
# [884]	train-auc:0.99784	test-auc:0.85156
# [885]	train-auc:0.99786	test-auc:0.85158
# [886]	train-auc:0.99788	test-auc:0.85159
# [887]	train-auc:0.99789	test-auc:0.85158
# [888]	train-auc:0.99791	test-auc:0.85155
# [889]	train-auc:0.99794	test-auc:0.85154
# [890]	train-auc:0.99795	test-auc:0.85154
# [891]	train-auc:0.99798	test-auc:0.85159
# [892]	train-auc:0.99800	test-auc:0.85158
# [893]	train-auc:0.99801	test-auc:0.85155
# [894]	train-auc:0.99803	test-auc:0.85155
# [895]	train-auc:0.99805	test-auc:0.85155
# [896]	train-auc:0.99806	test-auc:0.85159
# [897]	train-auc:0.99808	test-auc:0.85156
# [898]	train-auc:0.99809	test-auc:0.85157
# [899]	train-auc:0.99812	test-auc:0.85158
# [900]	train-auc:0.99813	test-auc:0.85157
# [901]	train-auc:0.99815	test-auc:0.85160
# [902]	train-auc:0.99816	test-auc:0.85162
# [903]	train-auc:0.99817	test-auc:0.85162
# [904]	train-auc:0.99819	test-auc:0.85167
# [905]	train-auc:0.99820	test-auc:0.85172
# [906]	train-auc:0.99822	test-auc:0.85167
# [907]	train-auc:0.99823	test-auc:0.85165
# [908]	train-auc:0.99824	test-auc:0.85167
# [909]	train-auc:0.99825	test-auc:0.85166
# [910]	train-auc:0.99827	test-auc:0.85159
# [911]	train-auc:0.99828	test-auc:0.85164
# [912]	train-auc:0.99830	test-auc:0.85158
# [913]	train-auc:0.99831	test-auc:0.85161
# [914]	train-auc:0.99833	test-auc:0.85160
# [915]	train-auc:0.99834	test-auc:0.85164
# [916]	train-auc:0.99835	test-auc:0.85163
# [917]	train-auc:0.99836	test-auc:0.85164
# [918]	train-auc:0.99836	test-auc:0.85163
# [919]	train-auc:0.99838	test-auc:0.85162
# [920]	train-auc:0.99840	test-auc:0.85169
# [921]	train-auc:0.99842	test-auc:0.85163
# [922]	train-auc:0.99842	test-auc:0.85163
# [923]	train-auc:0.99844	test-auc:0.85165
# [924]	train-auc:0.99845	test-auc:0.85164
# [925]	train-auc:0.99846	test-auc:0.85164
# [926]	train-auc:0.99848	test-auc:0.85167
# [927]	train-auc:0.99849	test-auc:0.85165
# [928]	train-auc:0.99850	test-auc:0.85163
# [929]	train-auc:0.99851	test-auc:0.85160
# [930]	train-auc:0.99852	test-auc:0.85162
# [931]	train-auc:0.99852	test-auc:0.85163
# [932]	train-auc:0.99854	test-auc:0.85164
# [933]	train-auc:0.99854	test-auc:0.85164
# [934]	train-auc:0.99855	test-auc:0.85160
# [935]	train-auc:0.99857	test-auc:0.85159
# [936]	train-auc:0.99858	test-auc:0.85156
# [937]	train-auc:0.99859	test-auc:0.85158
# [938]	train-auc:0.99859	test-auc:0.85157
# [939]	train-auc:0.99860	test-auc:0.85154
# [940]	train-auc:0.99861	test-auc:0.85158
# [941]	train-auc:0.99862	test-auc:0.85157
# [942]	train-auc:0.99863	test-auc:0.85160
# [943]	train-auc:0.99864	test-auc:0.85160
# [944]	train-auc:0.99865	test-auc:0.85159
# [945]	train-auc:0.99866	test-auc:0.85163
# [946]	train-auc:0.99866	test-auc:0.85162
# [947]	train-auc:0.99869	test-auc:0.85158
# [948]	train-auc:0.99869	test-auc:0.85157
# [949]	train-auc:0.99871	test-auc:0.85156
# [950]	train-auc:0.99871	test-auc:0.85158
# [951]	train-auc:0.99872	test-auc:0.85157
# [952]	train-auc:0.99872	test-auc:0.85161
# [953]	train-auc:0.99874	test-auc:0.85163
# [954]	train-auc:0.99875	test-auc:0.85163
# [955]	train-auc:0.99875	test-auc:0.85162
# [956]	train-auc:0.99875	test-auc:0.85162
# [957]	train-auc:0.99876	test-auc:0.85164
# [958]	train-auc:0.99876	test-auc:0.85166
# [959]	train-auc:0.99878	test-auc:0.85167
# [960]	train-auc:0.99878	test-auc:0.85170
# [961]	train-auc:0.99878	test-auc:0.85170
# [962]	train-auc:0.99879	test-auc:0.85172
# [963]	train-auc:0.99880	test-auc:0.85183
# [964]	train-auc:0.99881	test-auc:0.85183
# [965]	train-auc:0.99882	test-auc:0.85186
# [966]	train-auc:0.99882	test-auc:0.85184
# [967]	train-auc:0.99882	test-auc:0.85188
# [968]	train-auc:0.99883	test-auc:0.85187
# [969]	train-auc:0.99884	test-auc:0.85187
# [970]	train-auc:0.99884	test-auc:0.85186
# [971]	train-auc:0.99884	test-auc:0.85184
# [972]	train-auc:0.99885	test-auc:0.85185
# [973]	train-auc:0.99886	test-auc:0.85186
# [974]	train-auc:0.99887	test-auc:0.85184
# [975]	train-auc:0.99887	test-auc:0.85185
# [976]	train-auc:0.99887	test-auc:0.85186
# [977]	train-auc:0.99887	test-auc:0.85184
# [978]	train-auc:0.99888	test-auc:0.85183
# [979]	train-auc:0.99889	test-auc:0.85183
# [980]	train-auc:0.99889	test-auc:0.85181
# [981]	train-auc:0.99890	test-auc:0.85181
# [982]	train-auc:0.99891	test-auc:0.85181
# [983]	train-auc:0.99891	test-auc:0.85183
# [984]	train-auc:0.99893	test-auc:0.85182
# [985]	train-auc:0.99894	test-auc:0.85182
# [986]	train-auc:0.99894	test-auc:0.85183
# [987]	train-auc:0.99895	test-auc:0.85186
# [988]	train-auc:0.99896	test-auc:0.85181
# [989]	train-auc:0.99896	test-auc:0.85181
# [990]	train-auc:0.99896	test-auc:0.85177
# [991]	train-auc:0.99897	test-auc:0.85178
# [992]	train-auc:0.99899	test-auc:0.85174
# [993]	train-auc:0.99900	test-auc:0.85181
# [994]	train-auc:0.99901	test-auc:0.85181
# [995]	train-auc:0.99901	test-auc:0.85182
# [996]	train-auc:0.99901	test-auc:0.85185
# [997]	train-auc:0.99902	test-auc:0.85178
# [998]	train-auc:0.99904	test-auc:0.85182
# [999]	train-auc:0.99905	test-auc:0.85181

# %%
pd.DataFrame(pred).to_csv('submissions/xgb_pred.csv')

# %%
#bst.fit(df_train.values, Y.values)
#0.9692300714861747
metrics.roc_auc_score(Y.values, bst.predict(xgb.DMatrix(df_train.values)))
# Out:
# 0.9778278381122448

# %%
pred_proba = bst.predict(xgb.DMatrix(df_pred.values))

#pred_proba = xgbm.predict_proba(df_pred.values)[:,1]]

# %%
submittion = pd.DataFrame([unlabeled.encounter_id,pred_proba]).T
submittion.encounter_id = submittion.encounter_id.astype('int32')
submittion.set_index('encounter_id',inplace=True)
submittion.columns = ['diabetes_mellitus']
submittion.to_csv('submissions/SolutionWiDS2021_XGB_1000_epochs_onehot_pca.csv')

# %% [markdown]
# ## XGB fit on the entire dataset

# %%
xg_train = xgb.DMatrix(df_train.values, label=Y)
xg_test = xgb.DMatrix(X_val.values, label=y_val)

# %%
wandb.init(project="wids_2021", sync_tensorboard=True)
config = wandb.config


param = {'subsample': 1.0, 
         'num_leaves': 10, 
         'min_child_weight': 1, 
         'max_depth': 6, 
         'learning_rate': 0.1, 
         'gamma': 1.5, 
         'colsample_bytree': .6,
         'n_estimators':1000,
          'eval_metric':'auc',
          'objective': 'binary:logistic',
          'early_stopping_rounds':50}

# wandb.config.update(params)

watchlist = [(xg_train, 'train'), (xg_test, 'test')]
num_round = 1000
bst = xgb.train(param, xg_train, num_round, watchlist, callbacks=[wandb.xgboost.wandb_callback()])

# get prediction
pred = bst.predict(xg_test)
# Out:
# Finishing last run (ID:2negeqb6) before initializing another...
# <br/>Waiting for W&B process to finish, PID 23407<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/jupyter/wids/wandb/run-20210210_215519-2negeqb6/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/jupyter/wids/wandb/run-20210210_215519-2negeqb6/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train-auc</td><td>0.96323</td></tr><tr><td>test-auc</td><td>0.96416</td></tr><tr><td>_step</td><td>999</td></tr><tr><td>_runtime</td><td>1546</td></tr><tr><td>_timestamp</td><td>1612995669</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train-auc</td><td>▁▂▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>test-auc</td><td>▁▂▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">bumbling-sky-127</strong>: <a href="https://wandb.ai/mariapaskevich/wids_2021/runs/2negeqb6" target="_blank">https://wandb.ai/mariapaskevich/wids_2021/runs/2negeqb6</a><br/>
# ...Successfully finished last run (ID:2negeqb6). Initializing new run:<br/><br/>
# wandb: wandb version 0.10.18 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.13<br/>
#                 Syncing run <strong style="color:#cdcd00">balmy-water-128</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/mariapaskevich/wids_2021" target="_blank">https://wandb.ai/mariapaskevich/wids_2021</a><br/>
#                 Run page: <a href="https://wandb.ai/mariapaskevich/wids_2021/runs/2s8krkhe" target="_blank">https://wandb.ai/mariapaskevich/wids_2021/runs/2s8krkhe</a><br/>
#                 Run data is saved locally in <code>/home/jupyter/wids/wandb/run-20210210_223235-2s8krkhe</code><br/><br/>
# [22:32:41] WARNING: ../src/learner.cc:541:
# Parameters: { early_stopping_rounds, n_estimators, num_leaves } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-auc:0.81724	test-auc:0.81474
# [1]	train-auc:0.82481	test-auc:0.82294
# [2]	train-auc:0.82825	test-auc:0.82599
# [3]	train-auc:0.83127	test-auc:0.82937
# [4]	train-auc:0.83399	test-auc:0.83197
# [5]	train-auc:0.83592	test-auc:0.83387
# [6]	train-auc:0.83762	test-auc:0.83547
# [7]	train-auc:0.83864	test-auc:0.83657
# [8]	train-auc:0.83928	test-auc:0.83716
# [9]	train-auc:0.84061	test-auc:0.83857
# [10]	train-auc:0.84167	test-auc:0.83982
# [11]	train-auc:0.84283	test-auc:0.84096
# [12]	train-auc:0.84425	test-auc:0.84227
# [13]	train-auc:0.84528	test-auc:0.84346
# [14]	train-auc:0.84659	test-auc:0.84468
# [15]	train-auc:0.84751	test-auc:0.84564
# [16]	train-auc:0.84836	test-auc:0.84656
# [17]	train-auc:0.84932	test-auc:0.84748
# [18]	train-auc:0.85011	test-auc:0.84814
# [19]	train-auc:0.85078	test-auc:0.84886
# [20]	train-auc:0.85152	test-auc:0.84951
# [21]	train-auc:0.85214	test-auc:0.85024
# [22]	train-auc:0.85309	test-auc:0.85116
# [23]	train-auc:0.85376	test-auc:0.85198
# [24]	train-auc:0.85462	test-auc:0.85303
# [25]	train-auc:0.85545	test-auc:0.85385
# [26]	train-auc:0.85624	test-auc:0.85457
# [27]	train-auc:0.85693	test-auc:0.85524
# [28]	train-auc:0.85763	test-auc:0.85605
# [29]	train-auc:0.85824	test-auc:0.85659
# [30]	train-auc:0.85901	test-auc:0.85731
# [31]	train-auc:0.85979	test-auc:0.85810
# [32]	train-auc:0.86056	test-auc:0.85906
# [33]	train-auc:0.86130	test-auc:0.85984
# [34]	train-auc:0.86201	test-auc:0.86051
# [35]	train-auc:0.86275	test-auc:0.86128
# [36]	train-auc:0.86342	test-auc:0.86208
# [37]	train-auc:0.86421	test-auc:0.86296
# [38]	train-auc:0.86501	test-auc:0.86376
# [39]	train-auc:0.86565	test-auc:0.86432
# [40]	train-auc:0.86614	test-auc:0.86482
# [41]	train-auc:0.86687	test-auc:0.86562
# [42]	train-auc:0.86746	test-auc:0.86629
# [43]	train-auc:0.86803	test-auc:0.86688
# [44]	train-auc:0.86852	test-auc:0.86734
# [45]	train-auc:0.86913	test-auc:0.86796
# [46]	train-auc:0.86953	test-auc:0.86838
# [47]	train-auc:0.87008	test-auc:0.86896
# [48]	train-auc:0.87044	test-auc:0.86934
# [49]	train-auc:0.87065	test-auc:0.86960
# [50]	train-auc:0.87124	test-auc:0.87023
# [51]	train-auc:0.87153	test-auc:0.87051
# [52]	train-auc:0.87206	test-auc:0.87095
# [53]	train-auc:0.87245	test-auc:0.87135
# [54]	train-auc:0.87303	test-auc:0.87195
# [55]	train-auc:0.87331	test-auc:0.87228
# [56]	train-auc:0.87364	test-auc:0.87265
# [57]	train-auc:0.87397	test-auc:0.87298
# [58]	train-auc:0.87444	test-auc:0.87348
# [59]	train-auc:0.87473	test-auc:0.87379
# [60]	train-auc:0.87500	test-auc:0.87410
# [61]	train-auc:0.87546	test-auc:0.87453
# [62]	train-auc:0.87576	test-auc:0.87479
# [63]	train-auc:0.87597	test-auc:0.87494
# [64]	train-auc:0.87644	test-auc:0.87533
# [65]	train-auc:0.87667	test-auc:0.87558
# [66]	train-auc:0.87696	test-auc:0.87589
# [67]	train-auc:0.87728	test-auc:0.87614
# [68]	train-auc:0.87779	test-auc:0.87669
# [69]	train-auc:0.87802	test-auc:0.87692
# [70]	train-auc:0.87823	test-auc:0.87713
# [71]	train-auc:0.87855	test-auc:0.87746
# [72]	train-auc:0.87882	test-auc:0.87774
# [73]	train-auc:0.87938	test-auc:0.87831
# [74]	train-auc:0.87958	test-auc:0.87854
# [75]	train-auc:0.87984	test-auc:0.87886
# [76]	train-auc:0.88014	test-auc:0.87906
# [77]	train-auc:0.88031	test-auc:0.87926
# [78]	train-auc:0.88051	test-auc:0.87947
# [79]	train-auc:0.88069	test-auc:0.87965
# [80]	train-auc:0.88100	test-auc:0.87995
# [81]	train-auc:0.88122	test-auc:0.88015
# [82]	train-auc:0.88155	test-auc:0.88053
# [83]	train-auc:0.88168	test-auc:0.88065
# [84]	train-auc:0.88193	test-auc:0.88089
# [85]	train-auc:0.88223	test-auc:0.88120
# [86]	train-auc:0.88265	test-auc:0.88164
# [87]	train-auc:0.88284	test-auc:0.88182
# [88]	train-auc:0.88309	test-auc:0.88215
# [89]	train-auc:0.88334	test-auc:0.88239
# [90]	train-auc:0.88360	test-auc:0.88263
# [91]	train-auc:0.88372	test-auc:0.88275
# [92]	train-auc:0.88402	test-auc:0.88307
# [93]	train-auc:0.88419	test-auc:0.88323
# [94]	train-auc:0.88446	test-auc:0.88352
# [95]	train-auc:0.88467	test-auc:0.88375
# [96]	train-auc:0.88493	test-auc:0.88401
# [97]	train-auc:0.88530	test-auc:0.88435
# [98]	train-auc:0.88557	test-auc:0.88463
# [99]	train-auc:0.88572	test-auc:0.88479
# [100]	train-auc:0.88590	test-auc:0.88500
# [101]	train-auc:0.88607	test-auc:0.88517
# [102]	train-auc:0.88643	test-auc:0.88554
# [103]	train-auc:0.88664	test-auc:0.88577
# [104]	train-auc:0.88690	test-auc:0.88602
# [105]	train-auc:0.88702	test-auc:0.88615
# [106]	train-auc:0.88744	test-auc:0.88654
# [107]	train-auc:0.88783	test-auc:0.88692
# [108]	train-auc:0.88811	test-auc:0.88724
# [109]	train-auc:0.88826	test-auc:0.88742
# [110]	train-auc:0.88837	test-auc:0.88755
# [111]	train-auc:0.88849	test-auc:0.88766
# [112]	train-auc:0.88869	test-auc:0.88783
# [113]	train-auc:0.88898	test-auc:0.88812
# [114]	train-auc:0.88918	test-auc:0.88836
# [115]	train-auc:0.88955	test-auc:0.88874
# [116]	train-auc:0.88973	test-auc:0.88893
# [117]	train-auc:0.89009	test-auc:0.88934
# [118]	train-auc:0.89025	test-auc:0.88953
# [119]	train-auc:0.89060	test-auc:0.88987
# [120]	train-auc:0.89091	test-auc:0.89014
# [121]	train-auc:0.89107	test-auc:0.89031
# [122]	train-auc:0.89115	test-auc:0.89040
# [123]	train-auc:0.89127	test-auc:0.89052
# [124]	train-auc:0.89143	test-auc:0.89068
# [125]	train-auc:0.89169	test-auc:0.89095
# [126]	train-auc:0.89179	test-auc:0.89105
# [127]	train-auc:0.89202	test-auc:0.89125
# [128]	train-auc:0.89222	test-auc:0.89150
# [129]	train-auc:0.89241	test-auc:0.89171
# [130]	train-auc:0.89256	test-auc:0.89183
# [131]	train-auc:0.89279	test-auc:0.89210
# [132]	train-auc:0.89299	test-auc:0.89230
# [133]	train-auc:0.89320	test-auc:0.89251
# [134]	train-auc:0.89344	test-auc:0.89277
# [135]	train-auc:0.89359	test-auc:0.89295
# [136]	train-auc:0.89380	test-auc:0.89312
# [137]	train-auc:0.89405	test-auc:0.89338
# [138]	train-auc:0.89421	test-auc:0.89353
# [139]	train-auc:0.89435	test-auc:0.89367
# [140]	train-auc:0.89446	test-auc:0.89378
# [141]	train-auc:0.89458	test-auc:0.89389
# [142]	train-auc:0.89472	test-auc:0.89405
# [143]	train-auc:0.89480	test-auc:0.89413
# [144]	train-auc:0.89493	test-auc:0.89426
# [145]	train-auc:0.89520	test-auc:0.89453
# [146]	train-auc:0.89534	test-auc:0.89470
# [147]	train-auc:0.89554	test-auc:0.89487
# [148]	train-auc:0.89588	test-auc:0.89522
# [149]	train-auc:0.89606	test-auc:0.89540
# [150]	train-auc:0.89614	test-auc:0.89547
# [151]	train-auc:0.89624	test-auc:0.89558
# [152]	train-auc:0.89654	test-auc:0.89592
# [153]	train-auc:0.89663	test-auc:0.89600
# [154]	train-auc:0.89685	test-auc:0.89621
# [155]	train-auc:0.89694	test-auc:0.89629
# [156]	train-auc:0.89709	test-auc:0.89647
# [157]	train-auc:0.89733	test-auc:0.89669
# [158]	train-auc:0.89748	test-auc:0.89686
# [159]	train-auc:0.89763	test-auc:0.89702
# [160]	train-auc:0.89780	test-auc:0.89720
# [161]	train-auc:0.89801	test-auc:0.89740
# [162]	train-auc:0.89804	test-auc:0.89743
# [163]	train-auc:0.89826	test-auc:0.89764
# [164]	train-auc:0.89836	test-auc:0.89773
# [165]	train-auc:0.89855	test-auc:0.89793
# [166]	train-auc:0.89862	test-auc:0.89799
# [167]	train-auc:0.89867	test-auc:0.89803
# [168]	train-auc:0.89892	test-auc:0.89830
# [169]	train-auc:0.89921	test-auc:0.89858
# [170]	train-auc:0.89942	test-auc:0.89882
# [171]	train-auc:0.89953	test-auc:0.89891
# [172]	train-auc:0.89963	test-auc:0.89902
# [173]	train-auc:0.89975	test-auc:0.89915
# [174]	train-auc:0.90003	test-auc:0.89943
# [175]	train-auc:0.90013	test-auc:0.89951
# [176]	train-auc:0.90035	test-auc:0.89974
# [177]	train-auc:0.90048	test-auc:0.89989
# [178]	train-auc:0.90056	test-auc:0.89997
# [179]	train-auc:0.90071	test-auc:0.90012
# [180]	train-auc:0.90084	test-auc:0.90026
# [181]	train-auc:0.90091	test-auc:0.90033
# [182]	train-auc:0.90123	test-auc:0.90068
# [183]	train-auc:0.90132	test-auc:0.90080
# [184]	train-auc:0.90144	test-auc:0.90093
# [185]	train-auc:0.90160	test-auc:0.90107
# [186]	train-auc:0.90167	test-auc:0.90114
# [187]	train-auc:0.90178	test-auc:0.90122
# [188]	train-auc:0.90206	test-auc:0.90148
# [189]	train-auc:0.90218	test-auc:0.90161
# [190]	train-auc:0.90229	test-auc:0.90172
# [191]	train-auc:0.90244	test-auc:0.90188
# [192]	train-auc:0.90257	test-auc:0.90197
# [193]	train-auc:0.90269	test-auc:0.90213
# [194]	train-auc:0.90285	test-auc:0.90229
# [195]	train-auc:0.90305	test-auc:0.90251
# [196]	train-auc:0.90324	test-auc:0.90277
# [197]	train-auc:0.90340	test-auc:0.90292
# [198]	train-auc:0.90365	test-auc:0.90319
# [199]	train-auc:0.90370	test-auc:0.90325
# [200]	train-auc:0.90381	test-auc:0.90334
# [201]	train-auc:0.90388	test-auc:0.90342
# [202]	train-auc:0.90394	test-auc:0.90348
# [203]	train-auc:0.90422	test-auc:0.90375
# [204]	train-auc:0.90433	test-auc:0.90388
# [205]	train-auc:0.90450	test-auc:0.90405
# [206]	train-auc:0.90462	test-auc:0.90416
# [207]	train-auc:0.90476	test-auc:0.90426
# [208]	train-auc:0.90488	test-auc:0.90438
# [209]	train-auc:0.90502	test-auc:0.90455
# [210]	train-auc:0.90515	test-auc:0.90468
# [211]	train-auc:0.90521	test-auc:0.90479
# [212]	train-auc:0.90538	test-auc:0.90496
# [213]	train-auc:0.90545	test-auc:0.90503
# [214]	train-auc:0.90561	test-auc:0.90521
# [215]	train-auc:0.90570	test-auc:0.90531
# [216]	train-auc:0.90583	test-auc:0.90548
# [217]	train-auc:0.90600	test-auc:0.90562
# [218]	train-auc:0.90612	test-auc:0.90574
# [219]	train-auc:0.90620	test-auc:0.90580
# [220]	train-auc:0.90632	test-auc:0.90591
# [221]	train-auc:0.90639	test-auc:0.90599
# [222]	train-auc:0.90647	test-auc:0.90607
# [223]	train-auc:0.90656	test-auc:0.90615
# [224]	train-auc:0.90669	test-auc:0.90629
# [225]	train-auc:0.90682	test-auc:0.90643
# [226]	train-auc:0.90693	test-auc:0.90653
# [227]	train-auc:0.90714	test-auc:0.90671
# [228]	train-auc:0.90731	test-auc:0.90692
# [229]	train-auc:0.90745	test-auc:0.90705
# [230]	train-auc:0.90764	test-auc:0.90726
# [231]	train-auc:0.90777	test-auc:0.90738
# [232]	train-auc:0.90783	test-auc:0.90743
# [233]	train-auc:0.90796	test-auc:0.90757
# [234]	train-auc:0.90810	test-auc:0.90776
# [235]	train-auc:0.90824	test-auc:0.90794
# [236]	train-auc:0.90835	test-auc:0.90803
# [237]	train-auc:0.90857	test-auc:0.90824
# [238]	train-auc:0.90873	test-auc:0.90843
# [239]	train-auc:0.90883	test-auc:0.90852
# [240]	train-auc:0.90896	test-auc:0.90868
# [241]	train-auc:0.90907	test-auc:0.90879
# [242]	train-auc:0.90913	test-auc:0.90885
# [243]	train-auc:0.90918	test-auc:0.90891
# [244]	train-auc:0.90940	test-auc:0.90916
# [245]	train-auc:0.90946	test-auc:0.90922
# [246]	train-auc:0.90958	test-auc:0.90931
# [247]	train-auc:0.90965	test-auc:0.90940
# [248]	train-auc:0.90980	test-auc:0.90954
# [249]	train-auc:0.90994	test-auc:0.90970
# [250]	train-auc:0.91000	test-auc:0.90977
# [251]	train-auc:0.91021	test-auc:0.90999
# [252]	train-auc:0.91042	test-auc:0.91025
# [253]	train-auc:0.91048	test-auc:0.91033
# [254]	train-auc:0.91057	test-auc:0.91043
# [255]	train-auc:0.91071	test-auc:0.91054
# [256]	train-auc:0.91079	test-auc:0.91062
# [257]	train-auc:0.91086	test-auc:0.91070
# [258]	train-auc:0.91092	test-auc:0.91076
# [259]	train-auc:0.91098	test-auc:0.91082
# [260]	train-auc:0.91117	test-auc:0.91100
# [261]	train-auc:0.91124	test-auc:0.91105
# [262]	train-auc:0.91135	test-auc:0.91119
# [263]	train-auc:0.91157	test-auc:0.91139
# [264]	train-auc:0.91171	test-auc:0.91154
# [265]	train-auc:0.91176	test-auc:0.91158
# [266]	train-auc:0.91185	test-auc:0.91166
# [267]	train-auc:0.91198	test-auc:0.91178
# [268]	train-auc:0.91212	test-auc:0.91195
# [269]	train-auc:0.91215	test-auc:0.91199
# [270]	train-auc:0.91221	test-auc:0.91204
# [271]	train-auc:0.91232	test-auc:0.91212
# [272]	train-auc:0.91242	test-auc:0.91224
# [273]	train-auc:0.91252	test-auc:0.91237
# [274]	train-auc:0.91266	test-auc:0.91255
# [275]	train-auc:0.91282	test-auc:0.91270
# [276]	train-auc:0.91289	test-auc:0.91278
# [277]	train-auc:0.91298	test-auc:0.91288
# [278]	train-auc:0.91314	test-auc:0.91310
# [279]	train-auc:0.91331	test-auc:0.91326
# [280]	train-auc:0.91343	test-auc:0.91337
# [281]	train-auc:0.91349	test-auc:0.91344
# [282]	train-auc:0.91360	test-auc:0.91356
# [283]	train-auc:0.91372	test-auc:0.91367
# [284]	train-auc:0.91387	test-auc:0.91382
# [285]	train-auc:0.91399	test-auc:0.91393
# [286]	train-auc:0.91404	test-auc:0.91398
# [287]	train-auc:0.91426	test-auc:0.91422
# [288]	train-auc:0.91429	test-auc:0.91425
# [289]	train-auc:0.91438	test-auc:0.91436
# [290]	train-auc:0.91442	test-auc:0.91440
# [291]	train-auc:0.91452	test-auc:0.91450
# [292]	train-auc:0.91469	test-auc:0.91465
# [293]	train-auc:0.91486	test-auc:0.91487
# [294]	train-auc:0.91497	test-auc:0.91497
# [295]	train-auc:0.91505	test-auc:0.91503
# [296]	train-auc:0.91509	test-auc:0.91508
# [297]	train-auc:0.91520	test-auc:0.91517
# [298]	train-auc:0.91535	test-auc:0.91533
# [299]	train-auc:0.91550	test-auc:0.91549
# [300]	train-auc:0.91560	test-auc:0.91557
# [301]	train-auc:0.91569	test-auc:0.91565
# [302]	train-auc:0.91577	test-auc:0.91573
# [303]	train-auc:0.91586	test-auc:0.91583
# [304]	train-auc:0.91617	test-auc:0.91612
# [305]	train-auc:0.91626	test-auc:0.91623
# [306]	train-auc:0.91644	test-auc:0.91645
# [307]	train-auc:0.91652	test-auc:0.91652
# [308]	train-auc:0.91666	test-auc:0.91665
# [309]	train-auc:0.91676	test-auc:0.91675
# [310]	train-auc:0.91690	test-auc:0.91690
# [311]	train-auc:0.91699	test-auc:0.91697
# [312]	train-auc:0.91706	test-auc:0.91705
# [313]	train-auc:0.91722	test-auc:0.91723
# [314]	train-auc:0.91728	test-auc:0.91729
# [315]	train-auc:0.91737	test-auc:0.91742
# [316]	train-auc:0.91747	test-auc:0.91752
# [317]	train-auc:0.91759	test-auc:0.91760
# [318]	train-auc:0.91764	test-auc:0.91768
# [319]	train-auc:0.91775	test-auc:0.91783
# [320]	train-auc:0.91790	test-auc:0.91797
# [321]	train-auc:0.91801	test-auc:0.91808
# [322]	train-auc:0.91804	test-auc:0.91810
# [323]	train-auc:0.91812	test-auc:0.91816
# [324]	train-auc:0.91821	test-auc:0.91826
# [325]	train-auc:0.91830	test-auc:0.91837
# [326]	train-auc:0.91837	test-auc:0.91843
# [327]	train-auc:0.91847	test-auc:0.91853
# [328]	train-auc:0.91854	test-auc:0.91860
# [329]	train-auc:0.91862	test-auc:0.91869
# [330]	train-auc:0.91869	test-auc:0.91877
# [331]	train-auc:0.91880	test-auc:0.91887
# [332]	train-auc:0.91891	test-auc:0.91900
# [333]	train-auc:0.91897	test-auc:0.91906
# [334]	train-auc:0.91910	test-auc:0.91924
# [335]	train-auc:0.91916	test-auc:0.91929
# [336]	train-auc:0.91926	test-auc:0.91942
# [337]	train-auc:0.91935	test-auc:0.91951
# [338]	train-auc:0.91947	test-auc:0.91960
# [339]	train-auc:0.91957	test-auc:0.91970
# [340]	train-auc:0.91962	test-auc:0.91976
# [341]	train-auc:0.91966	test-auc:0.91980
# [342]	train-auc:0.91967	test-auc:0.91982
# [343]	train-auc:0.91971	test-auc:0.91985
# [344]	train-auc:0.91982	test-auc:0.91994
# [345]	train-auc:0.91998	test-auc:0.92012
# [346]	train-auc:0.92012	test-auc:0.92026
# [347]	train-auc:0.92028	test-auc:0.92042
# [348]	train-auc:0.92032	test-auc:0.92046
# [349]	train-auc:0.92037	test-auc:0.92051
# [350]	train-auc:0.92052	test-auc:0.92067
# [351]	train-auc:0.92063	test-auc:0.92079
# [352]	train-auc:0.92077	test-auc:0.92091
# [353]	train-auc:0.92087	test-auc:0.92101
# [354]	train-auc:0.92100	test-auc:0.92114
# [355]	train-auc:0.92120	test-auc:0.92138
# [356]	train-auc:0.92129	test-auc:0.92148
# [357]	train-auc:0.92139	test-auc:0.92160
# [358]	train-auc:0.92148	test-auc:0.92170
# [359]	train-auc:0.92154	test-auc:0.92176
# [360]	train-auc:0.92160	test-auc:0.92183
# [361]	train-auc:0.92170	test-auc:0.92193
# [362]	train-auc:0.92187	test-auc:0.92211
# [363]	train-auc:0.92205	test-auc:0.92226
# [364]	train-auc:0.92231	test-auc:0.92250
# [365]	train-auc:0.92243	test-auc:0.92261
# [366]	train-auc:0.92256	test-auc:0.92275
# [367]	train-auc:0.92261	test-auc:0.92280
# [368]	train-auc:0.92275	test-auc:0.92294
# [369]	train-auc:0.92283	test-auc:0.92304
# [370]	train-auc:0.92294	test-auc:0.92316
# [371]	train-auc:0.92299	test-auc:0.92321
# [372]	train-auc:0.92306	test-auc:0.92328
# [373]	train-auc:0.92309	test-auc:0.92332
# [374]	train-auc:0.92319	test-auc:0.92342
# [375]	train-auc:0.92320	test-auc:0.92344
# [376]	train-auc:0.92333	test-auc:0.92354
# [377]	train-auc:0.92337	test-auc:0.92361
# [378]	train-auc:0.92347	test-auc:0.92372
# [379]	train-auc:0.92353	test-auc:0.92379
# [380]	train-auc:0.92364	test-auc:0.92387
# [381]	train-auc:0.92368	test-auc:0.92392
# [382]	train-auc:0.92371	test-auc:0.92394
# [383]	train-auc:0.92383	test-auc:0.92405
# [384]	train-auc:0.92396	test-auc:0.92417
# [385]	train-auc:0.92399	test-auc:0.92422
# [386]	train-auc:0.92419	test-auc:0.92442
# [387]	train-auc:0.92437	test-auc:0.92458
# [388]	train-auc:0.92453	test-auc:0.92478
# [389]	train-auc:0.92470	test-auc:0.92494
# [390]	train-auc:0.92479	test-auc:0.92503
# [391]	train-auc:0.92490	test-auc:0.92514
# [392]	train-auc:0.92496	test-auc:0.92519
# [393]	train-auc:0.92500	test-auc:0.92524
# [394]	train-auc:0.92521	test-auc:0.92545
# [395]	train-auc:0.92541	test-auc:0.92562
# [396]	train-auc:0.92553	test-auc:0.92576
# [397]	train-auc:0.92564	test-auc:0.92583
# [398]	train-auc:0.92572	test-auc:0.92591
# [399]	train-auc:0.92579	test-auc:0.92598
# [400]	train-auc:0.92585	test-auc:0.92606
# [401]	train-auc:0.92589	test-auc:0.92610
# [402]	train-auc:0.92593	test-auc:0.92613
# [403]	train-auc:0.92603	test-auc:0.92625
# [404]	train-auc:0.92613	test-auc:0.92632
# [405]	train-auc:0.92622	test-auc:0.92641
# [406]	train-auc:0.92626	test-auc:0.92645
# [407]	train-auc:0.92627	test-auc:0.92647
# [408]	train-auc:0.92631	test-auc:0.92650
# [409]	train-auc:0.92650	test-auc:0.92670
# [410]	train-auc:0.92654	test-auc:0.92674
# [411]	train-auc:0.92661	test-auc:0.92680
# [412]	train-auc:0.92664	test-auc:0.92683
# [413]	train-auc:0.92674	test-auc:0.92692
# [414]	train-auc:0.92694	test-auc:0.92712
# [415]	train-auc:0.92704	test-auc:0.92722
# [416]	train-auc:0.92708	test-auc:0.92726
# [417]	train-auc:0.92720	test-auc:0.92739
# [418]	train-auc:0.92724	test-auc:0.92745
# [419]	train-auc:0.92737	test-auc:0.92757
# [420]	train-auc:0.92739	test-auc:0.92759
# [421]	train-auc:0.92750	test-auc:0.92765
# [422]	train-auc:0.92757	test-auc:0.92772
# [423]	train-auc:0.92770	test-auc:0.92785
# [424]	train-auc:0.92775	test-auc:0.92790
# [425]	train-auc:0.92784	test-auc:0.92799
# [426]	train-auc:0.92796	test-auc:0.92814
# [427]	train-auc:0.92804	test-auc:0.92821
# [428]	train-auc:0.92814	test-auc:0.92832
# [429]	train-auc:0.92824	test-auc:0.92841
# [430]	train-auc:0.92838	test-auc:0.92854
# [431]	train-auc:0.92851	test-auc:0.92867
# [432]	train-auc:0.92861	test-auc:0.92876
# [433]	train-auc:0.92867	test-auc:0.92882
# [434]	train-auc:0.92875	test-auc:0.92890
# [435]	train-auc:0.92886	test-auc:0.92904
# [436]	train-auc:0.92888	test-auc:0.92906
# [437]	train-auc:0.92898	test-auc:0.92918
# [438]	train-auc:0.92903	test-auc:0.92922
# [439]	train-auc:0.92909	test-auc:0.92928
# [440]	train-auc:0.92913	test-auc:0.92932
# [441]	train-auc:0.92928	test-auc:0.92946
# [442]	train-auc:0.92933	test-auc:0.92953
# [443]	train-auc:0.92941	test-auc:0.92960
# [444]	train-auc:0.92947	test-auc:0.92966
# [445]	train-auc:0.92952	test-auc:0.92971
# [446]	train-auc:0.92959	test-auc:0.92977
# [447]	train-auc:0.92968	test-auc:0.92987
# [448]	train-auc:0.92976	test-auc:0.92994
# [449]	train-auc:0.92990	test-auc:0.93009
# [450]	train-auc:0.92993	test-auc:0.93012
# [451]	train-auc:0.93008	test-auc:0.93026
# [452]	train-auc:0.93023	test-auc:0.93046
# [453]	train-auc:0.93025	test-auc:0.93049
# [454]	train-auc:0.93035	test-auc:0.93058
# [455]	train-auc:0.93042	test-auc:0.93067
# [456]	train-auc:0.93049	test-auc:0.93073
# [457]	train-auc:0.93056	test-auc:0.93083
# [458]	train-auc:0.93062	test-auc:0.93090
# [459]	train-auc:0.93072	test-auc:0.93101
# [460]	train-auc:0.93081	test-auc:0.93111
# [461]	train-auc:0.93085	test-auc:0.93115
# [462]	train-auc:0.93089	test-auc:0.93118
# [463]	train-auc:0.93097	test-auc:0.93126
# [464]	train-auc:0.93105	test-auc:0.93135
# [465]	train-auc:0.93119	test-auc:0.93149
# [466]	train-auc:0.93132	test-auc:0.93158
# [467]	train-auc:0.93144	test-auc:0.93174
# [468]	train-auc:0.93154	test-auc:0.93183
# [469]	train-auc:0.93162	test-auc:0.93191
# [470]	train-auc:0.93170	test-auc:0.93198
# [471]	train-auc:0.93173	test-auc:0.93202
# [472]	train-auc:0.93176	test-auc:0.93204
# [473]	train-auc:0.93179	test-auc:0.93206
# [474]	train-auc:0.93192	test-auc:0.93218
# [475]	train-auc:0.93195	test-auc:0.93223
# [476]	train-auc:0.93200	test-auc:0.93227
# [477]	train-auc:0.93202	test-auc:0.93229
# [478]	train-auc:0.93212	test-auc:0.93237
# [479]	train-auc:0.93223	test-auc:0.93248
# [480]	train-auc:0.93230	test-auc:0.93255
# [481]	train-auc:0.93240	test-auc:0.93264
# [482]	train-auc:0.93246	test-auc:0.93273
# [483]	train-auc:0.93261	test-auc:0.93287
# [484]	train-auc:0.93265	test-auc:0.93291
# [485]	train-auc:0.93278	test-auc:0.93305
# [486]	train-auc:0.93289	test-auc:0.93318
# [487]	train-auc:0.93297	test-auc:0.93326
# [488]	train-auc:0.93310	test-auc:0.93337
# [489]	train-auc:0.93323	test-auc:0.93350
# [490]	train-auc:0.93331	test-auc:0.93359
# [491]	train-auc:0.93342	test-auc:0.93371
# [492]	train-auc:0.93351	test-auc:0.93379
# [493]	train-auc:0.93353	test-auc:0.93382
# [494]	train-auc:0.93359	test-auc:0.93391
# [495]	train-auc:0.93363	test-auc:0.93395
# [496]	train-auc:0.93370	test-auc:0.93402
# [497]	train-auc:0.93374	test-auc:0.93409
# [498]	train-auc:0.93378	test-auc:0.93412
# [499]	train-auc:0.93384	test-auc:0.93417
# [500]	train-auc:0.93395	test-auc:0.93426
# [501]	train-auc:0.93402	test-auc:0.93437
# [502]	train-auc:0.93410	test-auc:0.93444
# [503]	train-auc:0.93415	test-auc:0.93449
# [504]	train-auc:0.93420	test-auc:0.93456
# [505]	train-auc:0.93432	test-auc:0.93469
# [506]	train-auc:0.93441	test-auc:0.93477
# [507]	train-auc:0.93450	test-auc:0.93487
# [508]	train-auc:0.93457	test-auc:0.93492
# [509]	train-auc:0.93470	test-auc:0.93506
# [510]	train-auc:0.93474	test-auc:0.93509
# [511]	train-auc:0.93482	test-auc:0.93517
# [512]	train-auc:0.93487	test-auc:0.93522
# [513]	train-auc:0.93490	test-auc:0.93526
# [514]	train-auc:0.93496	test-auc:0.93530
# [515]	train-auc:0.93505	test-auc:0.93539
# [516]	train-auc:0.93510	test-auc:0.93543
# [517]	train-auc:0.93516	test-auc:0.93547
# [518]	train-auc:0.93522	test-auc:0.93555
# [519]	train-auc:0.93526	test-auc:0.93559
# [520]	train-auc:0.93535	test-auc:0.93568
# [521]	train-auc:0.93539	test-auc:0.93571
# [522]	train-auc:0.93541	test-auc:0.93574
# [523]	train-auc:0.93550	test-auc:0.93585
# [524]	train-auc:0.93554	test-auc:0.93589
# [525]	train-auc:0.93559	test-auc:0.93595
# [526]	train-auc:0.93563	test-auc:0.93601
# [527]	train-auc:0.93563	test-auc:0.93602
# [528]	train-auc:0.93584	test-auc:0.93621
# [529]	train-auc:0.93593	test-auc:0.93630
# [530]	train-auc:0.93602	test-auc:0.93643
# [531]	train-auc:0.93610	test-auc:0.93651
# [532]	train-auc:0.93618	test-auc:0.93659
# [533]	train-auc:0.93625	test-auc:0.93668
# [534]	train-auc:0.93629	test-auc:0.93672
# [535]	train-auc:0.93641	test-auc:0.93685
# [536]	train-auc:0.93648	test-auc:0.93692
# [537]	train-auc:0.93658	test-auc:0.93701
# [538]	train-auc:0.93665	test-auc:0.93708
# [539]	train-auc:0.93673	test-auc:0.93717
# [540]	train-auc:0.93677	test-auc:0.93720
# [541]	train-auc:0.93678	test-auc:0.93721
# [542]	train-auc:0.93680	test-auc:0.93723
# [543]	train-auc:0.93690	test-auc:0.93733
# [544]	train-auc:0.93694	test-auc:0.93737
# [545]	train-auc:0.93698	test-auc:0.93743
# [546]	train-auc:0.93709	test-auc:0.93753
# [547]	train-auc:0.93717	test-auc:0.93760
# [548]	train-auc:0.93728	test-auc:0.93775
# [549]	train-auc:0.93738	test-auc:0.93782
# [550]	train-auc:0.93746	test-auc:0.93789
# [551]	train-auc:0.93749	test-auc:0.93792
# [552]	train-auc:0.93757	test-auc:0.93800
# [553]	train-auc:0.93766	test-auc:0.93809
# [554]	train-auc:0.93774	test-auc:0.93816
# [555]	train-auc:0.93780	test-auc:0.93824
# [556]	train-auc:0.93784	test-auc:0.93829
# [557]	train-auc:0.93791	test-auc:0.93834
# [558]	train-auc:0.93795	test-auc:0.93838
# [559]	train-auc:0.93801	test-auc:0.93844
# [560]	train-auc:0.93807	test-auc:0.93851
# [561]	train-auc:0.93811	test-auc:0.93855
# [562]	train-auc:0.93820	test-auc:0.93866
# [563]	train-auc:0.93825	test-auc:0.93871
# [564]	train-auc:0.93830	test-auc:0.93877
# [565]	train-auc:0.93839	test-auc:0.93887
# [566]	train-auc:0.93846	test-auc:0.93897
# [567]	train-auc:0.93848	test-auc:0.93900
# [568]	train-auc:0.93855	test-auc:0.93906
# [569]	train-auc:0.93859	test-auc:0.93910
# [570]	train-auc:0.93866	test-auc:0.93917
# [571]	train-auc:0.93870	test-auc:0.93921
# [572]	train-auc:0.93876	test-auc:0.93929
# [573]	train-auc:0.93879	test-auc:0.93934
# [574]	train-auc:0.93888	test-auc:0.93945
# [575]	train-auc:0.93895	test-auc:0.93950
# [576]	train-auc:0.93904	test-auc:0.93963
# [577]	train-auc:0.93913	test-auc:0.93972
# [578]	train-auc:0.93922	test-auc:0.93981
# [579]	train-auc:0.93923	test-auc:0.93982
# [580]	train-auc:0.93928	test-auc:0.93987
# [581]	train-auc:0.93933	test-auc:0.93992
# [582]	train-auc:0.93939	test-auc:0.93999
# [583]	train-auc:0.93943	test-auc:0.94003
# [584]	train-auc:0.93950	test-auc:0.94009
# [585]	train-auc:0.93957	test-auc:0.94017
# [586]	train-auc:0.93962	test-auc:0.94021
# [587]	train-auc:0.93965	test-auc:0.94024
# [588]	train-auc:0.93970	test-auc:0.94028
# [589]	train-auc:0.93971	test-auc:0.94029
# [590]	train-auc:0.93976	test-auc:0.94036
# [591]	train-auc:0.93986	test-auc:0.94048
# [592]	train-auc:0.93991	test-auc:0.94053
# [593]	train-auc:0.93995	test-auc:0.94058
# [594]	train-auc:0.94009	test-auc:0.94071
# [595]	train-auc:0.94015	test-auc:0.94074
# [596]	train-auc:0.94024	test-auc:0.94083
# [597]	train-auc:0.94030	test-auc:0.94089
# [598]	train-auc:0.94035	test-auc:0.94094
# [599]	train-auc:0.94038	test-auc:0.94098
# [600]	train-auc:0.94043	test-auc:0.94100
# [601]	train-auc:0.94047	test-auc:0.94104
# [602]	train-auc:0.94050	test-auc:0.94107
# [603]	train-auc:0.94052	test-auc:0.94110
# [604]	train-auc:0.94061	test-auc:0.94124
# [605]	train-auc:0.94072	test-auc:0.94139
# [606]	train-auc:0.94079	test-auc:0.94146
# [607]	train-auc:0.94087	test-auc:0.94154
# [608]	train-auc:0.94098	test-auc:0.94164
# [609]	train-auc:0.94103	test-auc:0.94170
# [610]	train-auc:0.94107	test-auc:0.94174
# [611]	train-auc:0.94114	test-auc:0.94183
# [612]	train-auc:0.94119	test-auc:0.94189
# [613]	train-auc:0.94125	test-auc:0.94196
# [614]	train-auc:0.94131	test-auc:0.94200
# [615]	train-auc:0.94134	test-auc:0.94202
# [616]	train-auc:0.94143	test-auc:0.94212
# [617]	train-auc:0.94147	test-auc:0.94219
# [618]	train-auc:0.94156	test-auc:0.94227
# [619]	train-auc:0.94176	test-auc:0.94245
# [620]	train-auc:0.94183	test-auc:0.94252
# [621]	train-auc:0.94193	test-auc:0.94262
# [622]	train-auc:0.94195	test-auc:0.94265
# [623]	train-auc:0.94204	test-auc:0.94275
# [624]	train-auc:0.94215	test-auc:0.94285
# [625]	train-auc:0.94229	test-auc:0.94300
# [626]	train-auc:0.94239	test-auc:0.94313
# [627]	train-auc:0.94254	test-auc:0.94326
# [628]	train-auc:0.94262	test-auc:0.94333
# [629]	train-auc:0.94270	test-auc:0.94344
# [630]	train-auc:0.94277	test-auc:0.94349
# [631]	train-auc:0.94282	test-auc:0.94357
# [632]	train-auc:0.94291	test-auc:0.94368
# [633]	train-auc:0.94296	test-auc:0.94374
# [634]	train-auc:0.94297	test-auc:0.94375
# [635]	train-auc:0.94301	test-auc:0.94380
# [636]	train-auc:0.94307	test-auc:0.94388
# [637]	train-auc:0.94319	test-auc:0.94399
# [638]	train-auc:0.94322	test-auc:0.94404
# [639]	train-auc:0.94326	test-auc:0.94407
# [640]	train-auc:0.94337	test-auc:0.94418
# [641]	train-auc:0.94340	test-auc:0.94421
# [642]	train-auc:0.94351	test-auc:0.94432
# [643]	train-auc:0.94358	test-auc:0.94441
# [644]	train-auc:0.94365	test-auc:0.94446
# [645]	train-auc:0.94371	test-auc:0.94452
# [646]	train-auc:0.94376	test-auc:0.94457
# [647]	train-auc:0.94381	test-auc:0.94461
# [648]	train-auc:0.94389	test-auc:0.94468
# [649]	train-auc:0.94395	test-auc:0.94474
# [650]	train-auc:0.94406	test-auc:0.94487
# [651]	train-auc:0.94418	test-auc:0.94500
# [652]	train-auc:0.94421	test-auc:0.94502
# [653]	train-auc:0.94429	test-auc:0.94510
# [654]	train-auc:0.94433	test-auc:0.94513
# [655]	train-auc:0.94438	test-auc:0.94517
# [656]	train-auc:0.94445	test-auc:0.94523
# [657]	train-auc:0.94446	test-auc:0.94524
# [658]	train-auc:0.94457	test-auc:0.94536
# [659]	train-auc:0.94462	test-auc:0.94541
# [660]	train-auc:0.94467	test-auc:0.94547
# [661]	train-auc:0.94470	test-auc:0.94550
# [662]	train-auc:0.94474	test-auc:0.94554
# [663]	train-auc:0.94481	test-auc:0.94562
# [664]	train-auc:0.94495	test-auc:0.94576
# [665]	train-auc:0.94502	test-auc:0.94581
# [666]	train-auc:0.94511	test-auc:0.94590
# [667]	train-auc:0.94522	test-auc:0.94600
# [668]	train-auc:0.94527	test-auc:0.94605
# [669]	train-auc:0.94532	test-auc:0.94610
# [670]	train-auc:0.94541	test-auc:0.94620
# [671]	train-auc:0.94544	test-auc:0.94625
# [672]	train-auc:0.94550	test-auc:0.94631
# [673]	train-auc:0.94562	test-auc:0.94641
# [674]	train-auc:0.94567	test-auc:0.94645
# [675]	train-auc:0.94578	test-auc:0.94658
# [676]	train-auc:0.94589	test-auc:0.94669
# [677]	train-auc:0.94602	test-auc:0.94680
# [678]	train-auc:0.94619	test-auc:0.94699
# [679]	train-auc:0.94626	test-auc:0.94706
# [680]	train-auc:0.94631	test-auc:0.94711
# [681]	train-auc:0.94638	test-auc:0.94721
# [682]	train-auc:0.94642	test-auc:0.94726
# [683]	train-auc:0.94658	test-auc:0.94740
# [684]	train-auc:0.94662	test-auc:0.94744
# [685]	train-auc:0.94664	test-auc:0.94745
# [686]	train-auc:0.94672	test-auc:0.94755
# [687]	train-auc:0.94677	test-auc:0.94761
# [688]	train-auc:0.94688	test-auc:0.94771
# [689]	train-auc:0.94689	test-auc:0.94774
# [690]	train-auc:0.94691	test-auc:0.94775
# [691]	train-auc:0.94693	test-auc:0.94777
# [692]	train-auc:0.94695	test-auc:0.94778
# [693]	train-auc:0.94699	test-auc:0.94783
# [694]	train-auc:0.94705	test-auc:0.94789
# [695]	train-auc:0.94713	test-auc:0.94797
# [696]	train-auc:0.94727	test-auc:0.94810
# [697]	train-auc:0.94742	test-auc:0.94822
# [698]	train-auc:0.94744	test-auc:0.94827
# [699]	train-auc:0.94751	test-auc:0.94833
# [700]	train-auc:0.94753	test-auc:0.94835
# [701]	train-auc:0.94757	test-auc:0.94839
# [702]	train-auc:0.94774	test-auc:0.94857
# [703]	train-auc:0.94782	test-auc:0.94866
# [704]	train-auc:0.94784	test-auc:0.94868
# [705]	train-auc:0.94788	test-auc:0.94873
# [706]	train-auc:0.94796	test-auc:0.94881
# [707]	train-auc:0.94801	test-auc:0.94886
# [708]	train-auc:0.94805	test-auc:0.94890
# [709]	train-auc:0.94809	test-auc:0.94896
# [710]	train-auc:0.94816	test-auc:0.94903
# [711]	train-auc:0.94826	test-auc:0.94915
# [712]	train-auc:0.94833	test-auc:0.94922
# [713]	train-auc:0.94837	test-auc:0.94925
# [714]	train-auc:0.94841	test-auc:0.94929
# [715]	train-auc:0.94843	test-auc:0.94931
# [716]	train-auc:0.94845	test-auc:0.94934
# [717]	train-auc:0.94847	test-auc:0.94935
# [718]	train-auc:0.94858	test-auc:0.94945
# [719]	train-auc:0.94862	test-auc:0.94948
# [720]	train-auc:0.94867	test-auc:0.94954
# [721]	train-auc:0.94876	test-auc:0.94964
# [722]	train-auc:0.94878	test-auc:0.94966
# [723]	train-auc:0.94883	test-auc:0.94971
# [724]	train-auc:0.94886	test-auc:0.94975
# [725]	train-auc:0.94891	test-auc:0.94983
# [726]	train-auc:0.94894	test-auc:0.94985
# [727]	train-auc:0.94901	test-auc:0.94992
# [728]	train-auc:0.94901	test-auc:0.94992
# [729]	train-auc:0.94910	test-auc:0.95002
# [730]	train-auc:0.94920	test-auc:0.95012
# [731]	train-auc:0.94926	test-auc:0.95017
# [732]	train-auc:0.94931	test-auc:0.95021
# [733]	train-auc:0.94936	test-auc:0.95025
# [734]	train-auc:0.94937	test-auc:0.95028
# [735]	train-auc:0.94945	test-auc:0.95036
# [736]	train-auc:0.94951	test-auc:0.95042
# [737]	train-auc:0.94957	test-auc:0.95049
# [738]	train-auc:0.94962	test-auc:0.95053
# [739]	train-auc:0.94966	test-auc:0.95059
# [740]	train-auc:0.94975	test-auc:0.95066
# [741]	train-auc:0.94983	test-auc:0.95076
# [742]	train-auc:0.94983	test-auc:0.95076
# [743]	train-auc:0.94985	test-auc:0.95078
# [744]	train-auc:0.94990	test-auc:0.95082
# [745]	train-auc:0.94996	test-auc:0.95088
# [746]	train-auc:0.95001	test-auc:0.95093
# [747]	train-auc:0.95004	test-auc:0.95098
# [748]	train-auc:0.95011	test-auc:0.95105
# [749]	train-auc:0.95016	test-auc:0.95110
# [750]	train-auc:0.95023	test-auc:0.95115
# [751]	train-auc:0.95028	test-auc:0.95120
# [752]	train-auc:0.95034	test-auc:0.95126
# [753]	train-auc:0.95048	test-auc:0.95139
# [754]	train-auc:0.95057	test-auc:0.95149
# [755]	train-auc:0.95063	test-auc:0.95154
# [756]	train-auc:0.95067	test-auc:0.95158
# [757]	train-auc:0.95068	test-auc:0.95161
# [758]	train-auc:0.95074	test-auc:0.95165
# [759]	train-auc:0.95083	test-auc:0.95176
# [760]	train-auc:0.95089	test-auc:0.95181
# [761]	train-auc:0.95092	test-auc:0.95185
# [762]	train-auc:0.95097	test-auc:0.95189
# [763]	train-auc:0.95103	test-auc:0.95195
# [764]	train-auc:0.95107	test-auc:0.95198
# [765]	train-auc:0.95112	test-auc:0.95203
# [766]	train-auc:0.95112	test-auc:0.95204
# [767]	train-auc:0.95121	test-auc:0.95214
# [768]	train-auc:0.95125	test-auc:0.95217
# [769]	train-auc:0.95128	test-auc:0.95220
# [770]	train-auc:0.95133	test-auc:0.95225
# [771]	train-auc:0.95137	test-auc:0.95229
# [772]	train-auc:0.95146	test-auc:0.95236
# [773]	train-auc:0.95152	test-auc:0.95243
# [774]	train-auc:0.95160	test-auc:0.95251
# [775]	train-auc:0.95165	test-auc:0.95257
# [776]	train-auc:0.95170	test-auc:0.95261
# [777]	train-auc:0.95175	test-auc:0.95267
# [778]	train-auc:0.95182	test-auc:0.95275
# [779]	train-auc:0.95185	test-auc:0.95279
# [780]	train-auc:0.95190	test-auc:0.95283
# [781]	train-auc:0.95196	test-auc:0.95288
# [782]	train-auc:0.95208	test-auc:0.95301
# [783]	train-auc:0.95213	test-auc:0.95307
# [784]	train-auc:0.95216	test-auc:0.95311
# [785]	train-auc:0.95217	test-auc:0.95313
# [786]	train-auc:0.95226	test-auc:0.95322
# [787]	train-auc:0.95230	test-auc:0.95327
# [788]	train-auc:0.95236	test-auc:0.95331
# [789]	train-auc:0.95242	test-auc:0.95337
# [790]	train-auc:0.95251	test-auc:0.95347
# [791]	train-auc:0.95260	test-auc:0.95354
# [792]	train-auc:0.95264	test-auc:0.95358
# [793]	train-auc:0.95271	test-auc:0.95363
# [794]	train-auc:0.95273	test-auc:0.95365
# [795]	train-auc:0.95277	test-auc:0.95370
# [796]	train-auc:0.95285	test-auc:0.95379
# [797]	train-auc:0.95293	test-auc:0.95386
# [798]	train-auc:0.95297	test-auc:0.95389
# [799]	train-auc:0.95305	test-auc:0.95398
# [800]	train-auc:0.95317	test-auc:0.95408
# [801]	train-auc:0.95325	test-auc:0.95416
# [802]	train-auc:0.95334	test-auc:0.95425
# [803]	train-auc:0.95337	test-auc:0.95430
# [804]	train-auc:0.95348	test-auc:0.95440
# [805]	train-auc:0.95357	test-auc:0.95450
# [806]	train-auc:0.95362	test-auc:0.95455
# [807]	train-auc:0.95371	test-auc:0.95462
# [808]	train-auc:0.95375	test-auc:0.95466
# [809]	train-auc:0.95379	test-auc:0.95472
# [810]	train-auc:0.95380	test-auc:0.95473
# [811]	train-auc:0.95386	test-auc:0.95479
# [812]	train-auc:0.95393	test-auc:0.95485
# [813]	train-auc:0.95394	test-auc:0.95487
# [814]	train-auc:0.95395	test-auc:0.95488
# [815]	train-auc:0.95405	test-auc:0.95496
# [816]	train-auc:0.95414	test-auc:0.95508
# [817]	train-auc:0.95424	test-auc:0.95518
# [818]	train-auc:0.95435	test-auc:0.95530
# [819]	train-auc:0.95445	test-auc:0.95539
# [820]	train-auc:0.95450	test-auc:0.95544
# [821]	train-auc:0.95461	test-auc:0.95554
# [822]	train-auc:0.95468	test-auc:0.95560
# [823]	train-auc:0.95473	test-auc:0.95564
# [824]	train-auc:0.95475	test-auc:0.95567
# [825]	train-auc:0.95483	test-auc:0.95576
# [826]	train-auc:0.95488	test-auc:0.95581
# [827]	train-auc:0.95501	test-auc:0.95590
# [828]	train-auc:0.95505	test-auc:0.95596
# [829]	train-auc:0.95509	test-auc:0.95600
# [830]	train-auc:0.95512	test-auc:0.95603
# [831]	train-auc:0.95519	test-auc:0.95611
# [832]	train-auc:0.95523	test-auc:0.95615
# [833]	train-auc:0.95527	test-auc:0.95622
# [834]	train-auc:0.95532	test-auc:0.95627
# [835]	train-auc:0.95535	test-auc:0.95632
# [836]	train-auc:0.95540	test-auc:0.95636
# [837]	train-auc:0.95542	test-auc:0.95638
# [838]	train-auc:0.95548	test-auc:0.95644
# [839]	train-auc:0.95549	test-auc:0.95645
# [840]	train-auc:0.95562	test-auc:0.95657
# [841]	train-auc:0.95564	test-auc:0.95660
# [842]	train-auc:0.95569	test-auc:0.95665
# [843]	train-auc:0.95576	test-auc:0.95672
# [844]	train-auc:0.95582	test-auc:0.95679
# [845]	train-auc:0.95596	test-auc:0.95693
# [846]	train-auc:0.95603	test-auc:0.95698
# [847]	train-auc:0.95605	test-auc:0.95701
# [848]	train-auc:0.95609	test-auc:0.95705
# [849]	train-auc:0.95615	test-auc:0.95711
# [850]	train-auc:0.95627	test-auc:0.95723
# [851]	train-auc:0.95629	test-auc:0.95727
# [852]	train-auc:0.95631	test-auc:0.95729
# [853]	train-auc:0.95635	test-auc:0.95733
# [854]	train-auc:0.95637	test-auc:0.95734
# [855]	train-auc:0.95639	test-auc:0.95736
# [856]	train-auc:0.95641	test-auc:0.95738
# [857]	train-auc:0.95646	test-auc:0.95742
# [858]	train-auc:0.95647	test-auc:0.95743
# [859]	train-auc:0.95651	test-auc:0.95747
# [860]	train-auc:0.95656	test-auc:0.95753
# [861]	train-auc:0.95661	test-auc:0.95758
# [862]	train-auc:0.95664	test-auc:0.95761
# [863]	train-auc:0.95665	test-auc:0.95762
# [864]	train-auc:0.95671	test-auc:0.95766
# [865]	train-auc:0.95671	test-auc:0.95766
# [866]	train-auc:0.95675	test-auc:0.95772
# [867]	train-auc:0.95682	test-auc:0.95780
# [868]	train-auc:0.95689	test-auc:0.95787
# [869]	train-auc:0.95692	test-auc:0.95790
# [870]	train-auc:0.95702	test-auc:0.95800
# [871]	train-auc:0.95711	test-auc:0.95810
# [872]	train-auc:0.95721	test-auc:0.95818
# [873]	train-auc:0.95723	test-auc:0.95820
# [874]	train-auc:0.95727	test-auc:0.95825
# [875]	train-auc:0.95739	test-auc:0.95835
# [876]	train-auc:0.95743	test-auc:0.95839
# [877]	train-auc:0.95744	test-auc:0.95840
# [878]	train-auc:0.95746	test-auc:0.95842
# [879]	train-auc:0.95748	test-auc:0.95844
# [880]	train-auc:0.95754	test-auc:0.95849
# [881]	train-auc:0.95758	test-auc:0.95854
# [882]	train-auc:0.95761	test-auc:0.95857
# [883]	train-auc:0.95766	test-auc:0.95863
# [884]	train-auc:0.95772	test-auc:0.95869
# [885]	train-auc:0.95782	test-auc:0.95879
# [886]	train-auc:0.95788	test-auc:0.95886
# [887]	train-auc:0.95792	test-auc:0.95890
# [888]	train-auc:0.95797	test-auc:0.95893
# [889]	train-auc:0.95797	test-auc:0.95893
# [890]	train-auc:0.95802	test-auc:0.95898
# [891]	train-auc:0.95807	test-auc:0.95903
# [892]	train-auc:0.95812	test-auc:0.95910
# [893]	train-auc:0.95818	test-auc:0.95914
# [894]	train-auc:0.95821	test-auc:0.95917
# [895]	train-auc:0.95828	test-auc:0.95926
# [896]	train-auc:0.95833	test-auc:0.95930
# [897]	train-auc:0.95836	test-auc:0.95932
# [898]	train-auc:0.95843	test-auc:0.95939
# [899]	train-auc:0.95854	test-auc:0.95950
# [900]	train-auc:0.95858	test-auc:0.95954
# [901]	train-auc:0.95869	test-auc:0.95965
# [902]	train-auc:0.95873	test-auc:0.95967
# [903]	train-auc:0.95877	test-auc:0.95972
# [904]	train-auc:0.95887	test-auc:0.95981
# [905]	train-auc:0.95889	test-auc:0.95983
# [906]	train-auc:0.95896	test-auc:0.95990
# [907]	train-auc:0.95899	test-auc:0.95995
# [908]	train-auc:0.95900	test-auc:0.95996
# [909]	train-auc:0.95908	test-auc:0.96005
# [910]	train-auc:0.95914	test-auc:0.96011
# [911]	train-auc:0.95918	test-auc:0.96014
# [912]	train-auc:0.95927	test-auc:0.96025
# [913]	train-auc:0.95932	test-auc:0.96028
# [914]	train-auc:0.95932	test-auc:0.96029
# [915]	train-auc:0.95936	test-auc:0.96032
# [916]	train-auc:0.95944	test-auc:0.96038
# [917]	train-auc:0.95952	test-auc:0.96047
# [918]	train-auc:0.95960	test-auc:0.96055
# [919]	train-auc:0.95964	test-auc:0.96061
# [920]	train-auc:0.95966	test-auc:0.96063
# [921]	train-auc:0.95972	test-auc:0.96068
# [922]	train-auc:0.95975	test-auc:0.96072
# [923]	train-auc:0.95976	test-auc:0.96074
# [924]	train-auc:0.95985	test-auc:0.96082
# [925]	train-auc:0.95992	test-auc:0.96088
# [926]	train-auc:0.95995	test-auc:0.96093
# [927]	train-auc:0.95998	test-auc:0.96096
# [928]	train-auc:0.96010	test-auc:0.96106
# [929]	train-auc:0.96023	test-auc:0.96119
# [930]	train-auc:0.96028	test-auc:0.96124
# [931]	train-auc:0.96035	test-auc:0.96131
# [932]	train-auc:0.96039	test-auc:0.96135
# [933]	train-auc:0.96045	test-auc:0.96141
# [934]	train-auc:0.96048	test-auc:0.96144
# [935]	train-auc:0.96059	test-auc:0.96154
# [936]	train-auc:0.96067	test-auc:0.96162
# [937]	train-auc:0.96075	test-auc:0.96170
# [938]	train-auc:0.96085	test-auc:0.96184
# [939]	train-auc:0.96088	test-auc:0.96186
# [940]	train-auc:0.96093	test-auc:0.96191
# [941]	train-auc:0.96100	test-auc:0.96197
# [942]	train-auc:0.96113	test-auc:0.96210
# [943]	train-auc:0.96115	test-auc:0.96213
# [944]	train-auc:0.96118	test-auc:0.96215
# [945]	train-auc:0.96120	test-auc:0.96217
# [946]	train-auc:0.96124	test-auc:0.96222
# [947]	train-auc:0.96128	test-auc:0.96227
# [948]	train-auc:0.96133	test-auc:0.96231
# [949]	train-auc:0.96136	test-auc:0.96237
# [950]	train-auc:0.96138	test-auc:0.96239
# [951]	train-auc:0.96141	test-auc:0.96242
# [952]	train-auc:0.96147	test-auc:0.96249
# [953]	train-auc:0.96154	test-auc:0.96256
# [954]	train-auc:0.96157	test-auc:0.96258
# [955]	train-auc:0.96160	test-auc:0.96261
# [956]	train-auc:0.96161	test-auc:0.96263
# [957]	train-auc:0.96168	test-auc:0.96269
# [958]	train-auc:0.96174	test-auc:0.96274
# [959]	train-auc:0.96176	test-auc:0.96277
# [960]	train-auc:0.96178	test-auc:0.96278
# [961]	train-auc:0.96184	test-auc:0.96283
# [962]	train-auc:0.96187	test-auc:0.96287
# [963]	train-auc:0.96193	test-auc:0.96291
# [964]	train-auc:0.96196	test-auc:0.96295
# [965]	train-auc:0.96198	test-auc:0.96296
# [966]	train-auc:0.96200	test-auc:0.96298
# [967]	train-auc:0.96201	test-auc:0.96299
# [968]	train-auc:0.96206	test-auc:0.96303
# [969]	train-auc:0.96208	test-auc:0.96305
# [970]	train-auc:0.96210	test-auc:0.96308
# [971]	train-auc:0.96212	test-auc:0.96310
# [972]	train-auc:0.96213	test-auc:0.96311
# [973]	train-auc:0.96214	test-auc:0.96311
# [974]	train-auc:0.96219	test-auc:0.96315
# [975]	train-auc:0.96228	test-auc:0.96321
# [976]	train-auc:0.96232	test-auc:0.96325
# [977]	train-auc:0.96235	test-auc:0.96328
# [978]	train-auc:0.96239	test-auc:0.96334
# [979]	train-auc:0.96241	test-auc:0.96334
# [980]	train-auc:0.96245	test-auc:0.96338
# [981]	train-auc:0.96251	test-auc:0.96341
# [982]	train-auc:0.96255	test-auc:0.96345
# [983]	train-auc:0.96266	test-auc:0.96357
# [984]	train-auc:0.96274	test-auc:0.96365
# [985]	train-auc:0.96275	test-auc:0.96365
# [986]	train-auc:0.96278	test-auc:0.96368
# [987]	train-auc:0.96280	test-auc:0.96371
# [988]	train-auc:0.96283	test-auc:0.96373
# [989]	train-auc:0.96288	test-auc:0.96378
# [990]	train-auc:0.96290	test-auc:0.96379
# [991]	train-auc:0.96292	test-auc:0.96382
# [992]	train-auc:0.96293	test-auc:0.96383
# [993]	train-auc:0.96295	test-auc:0.96385
# [994]	train-auc:0.96301	test-auc:0.96393
# [995]	train-auc:0.96304	test-auc:0.96395
# [996]	train-auc:0.96307	test-auc:0.96398
# [997]	train-auc:0.96308	test-auc:0.96400
# [998]	train-auc:0.96317	test-auc:0.96409
# [999]	train-auc:0.96323	test-auc:0.96416

# %%
pred_proba = bst.predict(xgb.DMatrix(df_pred.values))

submittion = pd.DataFrame([unlabeled.encounter_id,pred_proba]).T
submittion.encounter_id = submittion.encounter_id.astype('int32')
submittion.set_index('encounter_id',inplace=True)
submittion.columns = ['diabetes_mellitus']
submittion.to_csv('SolutionWiDS2021_XGB_1000_epochs_onehot_entire_dataset.csv')

# %% [markdown]
# ### CV with random hpopt

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

# A parameter grid for XGBoost
params = {
        'min_child_weight': [1, 5],
        'gamma': [0.5, 1.5, 3],
        'subsample': [0.6, 1.0],
        'colsample_bytree': [0.6, 1.0],
        'max_depth': [4, 5, 6],
        'num_leaves': [10, 20, 30],
        'learning_rate': [0.01, 0.1, 0.2, 0.4]
        }

# %%
xgb = XGBClassifier(n_estimators=200, objective='binary:logistic', verbose=1)

# %%
folds = 4
param_comb = 250

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)

random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=param_comb, scoring='roc_auc', 
                                   n_jobs=32, cv=skf.split(df_train.values, Y), verbose=3, 
                                   random_state=1001)

# %%
# Here we go
import time
start=time.time()
random_search.fit(df_train.values, Y)
print(time.time()-start)
# Out:
# Fitting 4 folds for each of 250 candidates, totalling 1000 fits

# %%
random_search
# Out:
# RandomizedSearchCV(cv=<generator object _BaseKFold.split at 0x7f7cb6aeb5d0>,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, gamma=None,
#                                            gpu_id=None, importance_type='gain',
#                                            interaction_constraints=None,
#                                            learning_rate=None,
#                                            max_delta_step=None, max_depth=None,
#                                            min_child_weight=None, missing...
#                                            scale_pos_weight=None,
#                                            subsample=None, tree_method=None,
#                                            validate_parameters=None, verbose=1,
#                                            verbosity=None),
#                    n_iter=250, n_jobs=32,
#                    param_distributions={'colsample_bytree': [0.6, 1.0],
#                                         'gamma': [0.5, 1.5, 3],
#                                         'learning_rate': [0.01, 0.1, 0.2, 0.4],
#                                         'max_depth': [4, 5, 6],
#                                         'min_child_weight': [1, 5],
#                                         'num_leaves': [10, 20, 30],
#                                         'subsample': [0.6, 1.0]},
#                    random_state=1001, scoring='roc_auc', verbose=3)

# %%
print(random_search.best_params_)
# Out:
# {'subsample': 1.0, 'num_leaves': 10, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 1.5, 'colsample_bytree': 0.6}

# %%
pred_proba_rs = random_search.predict_proba(df_pred.values)

# %%
# (pred_proba, pred_proba_rs[:,1])

# %%
import matplotlib.pyplot as plt
plt.hist(pred_proba_rs[:,1])
# Out:
# (array([4852., 1681.,  888.,  690.,  572.,  461.,  417.,  394.,  224.,
#           55.]),
#  array([7.5848104e-04, 9.6810319e-02, 1.9286215e-01, 2.8891400e-01,
#         3.8496581e-01, 4.8101765e-01, 5.7706946e-01, 6.7312133e-01,
#         7.6917315e-01, 8.6522502e-01, 9.6127683e-01], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
submittion = pd.DataFrame([unlabeled.encounter_id,pred_proba_rs[:,1]]).T
submittion.encounter_id = submittion.encounter_id.astype('int32')
submittion.set_index('encounter_id',inplace=True)
submittion.columns = ['diabetes_mellitus']
submittion.fillna(0.5).to_csv('SolutionWiDS2021_XGB_200_epochs_CV_RandomSearch_200runs.csv')
